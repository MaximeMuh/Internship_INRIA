# %%
# !pip install torchdiffeq
# Out:
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (2.3.0+cu121)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.4.0->torchdiffeq) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.5.0->torchdiffeq)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.5.0->torchdiffeq)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 55.9 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.0->torchdiffeq) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.0->torchdiffeq) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchdiffeq
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 torchdiffeq-0.2.4

# %% [markdown]
# We define here the useful functions and class for the interpolant method explained in the previous notebook applied to the 2D case.

# %%
import torch
from torchdiffeq import odeint_adjoint as odeint
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import time
import sys
def make_It(path='linear', gamma = None, gamma_dot = None, gg_dot = None):
    """gamma function must be specified if using the trigonometric interpolant"""

    if path == 'linear':

        a      = lambda t: (1-t)
        adot   = lambda t: -1.0
        b      = lambda t: t
        bdot   = lambda t: 1.0
        It   = lambda t, x0, x1: a(t)*x0 + b(t)*x1
        dtIt = lambda t, x0, x1: adot(t)*x0 + bdot(t)*x1

    elif path == 'trig':
        if gamma == None:
            raise TypeError("Gamma function must be provided for trigonometric interpolant!")
        a    = lambda t: torch.sqrt(1 - gamma(t)**2)*torch.cos(0.5*math.pi*t)
        b    = lambda t: torch.sqrt(1 - gamma(t)**2)*torch.sin(0.5*math.pi*t)
        adot = lambda t: -gg_dot(t)/torch.sqrt(1 - gamma(t)**2)*torch.cos(0.5*math.pi*t) \
                                - 0.5*math.pi*torch.sqrt(1 - gamma(t)**2)*torch.sin(0.5*math.pi*t)
        bdot = lambda t: -gg_dot(t)/torch.sqrt(1 - gamma(t)**2)*torch.sin(0.5*math.pi*t) \
                                + 0.5*math.pi*torch.sqrt(1 - gamma(t)**2)*torch.cos(0.5*math.pi*t)

        It   = lambda t, x0, x1: a(t)*x0 + b(t)*x1
        dtIt = lambda t, x0, x1: adot(t)*x0 + bdot(t)*x1

    elif path == 'encoding-decoding':

        a    = lambda t: torch.where(t <= 0.5, torch.cos(math.pi*t)**2, torch.tensor(0.))
        adot = lambda t: torch.where(t <= 0.5, -2*math.pi*torch.cos(math.pi*t)*torch.sin(math.pi*t), torch.tensor(0.))
        b    = lambda t: torch.where(t > 0.5,  torch.cos(math.pi*t)**2, 0.)
        bdot = lambda t: torch.where(t > 0.5,  -2*math.pi*torch.cos(math.pi*t)*torch.sin(math.pi*t), torch.tensor(0.))
        It   = lambda t, x0, x1: a(t)*x0 + b(t)*x1
        dtIt = lambda t, x0, x1: adot(t)*x0 + bdot(t)*x1

    elif path == 'one-sided-linear':

        a      = lambda t: (1-t)
        adot   = lambda t: -1.0
        b      = lambda t: t
        bdot   = lambda t: 1.0

        It   = lambda t, x0, x1: a(t)*x0 + b(t)*x1
        dtIt = lambda t, x0, x1: adot(t)*x0 + bdot(t)*x1

    elif path == 'one-sided-trig':

        a      = lambda t: torch.cos(0.5*math.pi*t)
        adot   = lambda t: -0.5*math.pi*torch.sin(0.5*math.pi*t)
        b      = lambda t: torch.sin(0.5*math.pi*t)
        bdot   = lambda t: 0.5*math.pi*torch.cos(0.5*math.pi*t)


        It   = lambda t, x0, x1: a(t)*x0 + b(t)*x1
        dtIt = lambda t, x0, x1: adot(t)*x0 + bdot(t)*x1

    elif path == 'mirror':
        if gamma == None:
            raise TypeError("Gamma function must be provided for mirror interpolant!")

        a     = lambda t: gamma(t)
        adot  = lambda t: gamma_dot(t)
        b     = lambda t: torch.tensor(1.0)
        bdot  = lambda t: torch.tensor(0.0)

        It    = lambda t, x0, x1: b(t)*x1 + a(t)*x0
        dtIt  = lambda t, x0, x1: adot(t)*x0

    elif path == 'custom':
        return None, None, None

    else:
        raise NotImplementedError("The interpolant you specified is not implemented.")


    return It, dtIt, (a, adot, b, bdot)


def make_gamma(gamma_type = 'brownian', aval = None):
    """
    returns callable functions for gamma, gamma_dot,
    and gamma(t)*gamma_dot(t) to avoid numerical divide by 0s,
    e.g. if one is using the brownian (default) gamma.
    """
    if gamma_type == 'brownian':
        gamma = lambda t: torch.sqrt(t*(1-t))
        gamma_dot = lambda t: (1/(2*torch.sqrt(t*(1-t)))) * (1 -2*t)
        gg_dot = lambda t: (1/2)*(1-2*t)

    elif gamma_type == 'a-brownian':
        gamma = lambda t: torch.sqrt(a*t*(1-t))
        gamma_dot = lambda t: (1/(2*torch.sqrt(a*t*(1-t)))) * a*(1 -2*t)
        gg_dot = lambda t: (a/2)*(1-2*t)

    elif gamma_type == 'zero':
        gamma = gamma_dot = gg_dot = lambda t: torch.zeros_like(t)

    elif gamma_type == 'bsquared':
        gamma = lambda t: t*(1-t)
        gamma_dot = lambda t: 1 -2*t
        gg_dot = lambda t: gamma(t)*gamma_dot(t)

    elif gamma_type == 'sinesquared':
        gamma = lambda t: torch.sin(math.pi * t)**2
        gamma_dot = lambda t: 2*math.pi*torch.sin(math.pi * t)*torch.cos(math.pi*t)
        gg_dot = lambda t: gamma(t)*gamma_dot(t)

    elif gamma_type == 'sigmoid':
        f = torch.tensor(10.0)
        gamma = lambda t: torch.sigmoid(f*(t-(1/2)) + 1) - torch.sigmoid(f*(t-(1/2)) - 1) - torch.sigmoid((-f/2) + 1) + torch.sigmoid((-f/2) - 1)
        gamma_dot = lambda t: (-f)*( 1 - torch.sigmoid(-1 + f*(t - (1/2))) )*torch.sigmoid(-1 + f*(t - (1/2)))  + f*(1 - torch.sigmoid(1 + f*(t - (1/2)))  )*torch.sigmoid(1 + f*(t - (1/2)))
        gg_dot = lambda t: gamma(t)*gamma_dot(t)

    elif gamma_type == None:
        gamma     = lambda t: torch.zeros(1) ### no gamma
        gamma_dot = lambda t: torch.zeros(1) ### no gamma
        gg_dot    = lambda t: torch.zeros(1) ### no gamma

    else:
        raise NotImplementedError("The gamma you specified is not implemented.")


    return gamma, gamma_dot, gg_dot

class Interpolant(torch.nn.Module):
    """
    Class for all things interpoalnt $x_t = I_t(x_0, x_1) + \gamma(t)z.
    If path is one-sided, then interpolant constructs x_t = a(t) x_0 + b(t) x_1 with x_0 ~ N(0,1).

    path: str,    what type of interpolant to use, e.g. 'linear' for linear interpolant. see fabrics for options
    gamma_type:   what type of gamma function to use, e.g. 'brownian' for $\gamma(t) = \sqrt{t(1-t)}
    """
    def __init__(self, path, gamma_type,gamma= None,gamma_dot = None,gg_dot= None,It = None, dtIt= None):
        super(Interpolant, self).__init__()


        self.path = path
        if gamma == None:
            if self.path == 'one-sided-linear' or self.path == 'one-sided-trig':
              gamma_type = None

            self.gamma, self.gamma_dot, self.gg_dot = make_gamma(gamma_type=gamma_type)

        else:
            self.gamma, self.gamma_dot, self.gg_dot = gamma, gamma_dot, gg_dot

        if self.path == 'custom':
            print('Assuming interpolant was passed in directly...')
            self.It = It
            self.dtIt = dtIt
            assert self.It != None
            assert self.dtIt != None


        self.It, self.dtIt, ab = make_It(path, self.gamma, self.gamma_dot, self.gg_dot)
        self.a, self.adot, self.b, self.bdot = ab[0], ab[1], ab[2], ab[3]


    def calc_xt(self, t, x0, x1):
        if self.path =='one-sided-linear' or self.path == 'mirror' or self.path=='one-sided-trig':
            return self.It(t, x0, x1)
        else:
            z = torch.randn(x0.shape).to(t)
            return self.It(t, x0, x1) + self.gamma(t)*z, z

# %% [markdown]
# We define the many losses we can have. We need a losses for each functions we want to estimate ( velocity, score, denoiser) and also the path 'one-sided-linear' require a special loss because some simplifications in the formula occur.

# %%
def loss_per_sample_b(b, x0, x1, t, interpolant):
    """Compute the (variance-reduced) loss on an individual sample via antithetic sampling."""

    xt, z = interpolant.calc_xt(t, x0, x1)
    xt = xt.unsqueeze(0)
    dtIt        = interpolant.dtIt(t, x0, x1)
    gamma_dot   = interpolant.gamma_dot(t)
    bt         = b(xt, t)
    loss        = 0.5*torch.sum(bt**2) - torch.sum((dtIt + gamma_dot*z) * bt)
    return loss

def loss_per_sample_b_one_sided(b, x0, x1, t, interpolant):
    """Compute the (variance-reduced) loss on an individual sample via antithetic sampling."""

    xt = interpolant.calc_xt(t, x0, x1)
    xt, t = xt.unsqueeze(0), t.unsqueeze(0)
    dtIt        = interpolant.dtIt(t, x0, x1)
    gamma_dot   = interpolant.gamma_dot(t)
    bt         = b(xt, t)
    loss        = 0.5*torch.sum(bt**2) - torch.sum((dtIt) * bt)
    return loss

def loss_per_sample_s(
    s, x0, x1, t, interpolant
):
    """Compute the (variance-reduced) loss on an individual sample via antithetic sampling."""
    xt ,z = interpolant.calc_xt(t, x0, x1)
    xt ,t = xt.unsqueeze(0), t.unsqueeze(0)
    st = s(xt, t)
    loss = 0.5 * torch.sum(st**2) + (1 / interpolant.gamma(t)) * torch.sum(st * z)
    return loss

def loss_per_sample_eta(
    eta, x0, x1, t, interpolant
):
    """Compute the loss on an individual sample via antithetic sampling."""
    xt, z = interpolant.calc_xt(t, x0, x1)
    xt, t = xt.unsqueeze(0), t.unsqueeze(0)
    eta_val = eta(xt, t)
    return 0.5 * torch.sum(eta_val**2) + torch.sum(eta_val * z)


def loss_per_sample_one_sided_s(
    s, x0, x1, t, interpolant
):
    """Compute the loss on an individual sample via antithetic samples for x_t = sqrt(1-t)z + sqrt(t) x1 where z=x0."""
    xt, z = interpolant.calc_xt(t, x0, x1)
    xtt = xt.unsqueeze(0), t.unsqueeze(0)
    st = s(xt, t)
    alpha = interpolant.a(t)
    loss = 0.5 * torch.sum(st**2) + (1 / alpha) * torch.sum(st * x0)
    return loss

def loss_per_sample_one_sided_eta(
    eta, x0, x1, t, interpolant
):
    """Compute the loss on an individual sample via samples for x_t = alpha(t)z + beta(t) x1 where z=x0."""
    xt = interpolant.calc_xt(t, x0, x1)
    xt, t = xt.unsqueeze(0), t.unsqueeze(0)
    etat = eta(xt, t)
    loss = 0.5 * torch.sum(etat**2) + torch.sum(etat * x0)
    return loss


def make_loss(loss, bvseta, x0,x1, t, interpolant):
    """Convert a sample loss into a batched loss."""
    ## Share the batch dimension i for x0, x1, t
    in_dims_set = (None, 0, 0, 0, None)
    batched_loss = torch.vmap(loss, in_dims=in_dims_set, randomness='different')
    loss_val = batched_loss(bvseta, x0, x1, t, interpolant)
    loss_val = loss_val.mean()
    return loss_val

# %%
# class for SDE sampling.
class SDEIntegrator(torch.nn.Module):
    def __init__(self, b, s = None,eps=torch.tensor(0),interpolant=None,n_save=4,start_end = (0, 1), n_step = 100):
        super(SDEIntegrator, self).__init__()
        self.b =b
        self.s=s
        self.eps = eps
        self.n_save = n_save
        self.n_step = n_step
        self.start_end = start_end
        self.start, self.end = self.start_end
        self.ts = torch.linspace(self.start, self.end, self.n_step)
        self.dt = self.ts[1] - self.ts[0]
        self.interpolant = interpolant
        if self.s is None or self.eps == 0:
            self.bf = self.b
        else:
            self.bf = lambda x, t: self.b(x, t) + self.eps * self.s(x, t)




    def step_forward_heun(self, x: torch.tensor, t: torch.tensor) -> torch.tensor:
        """Heun Step -- see https://arxiv.org/pdf/2206.00364.pdf, Alg. 2"""
        dW = torch.sqrt(self.dt) * torch.randn_like(x)
        xhat = x + torch.sqrt(2 * self.eps) * dW
        K1 = self.bf(xhat, t + self.dt)
        xp = xhat + self.dt * K1
        K2 = self.bf(xp, t + self.dt)
        return xhat + 0.5 * self.dt * (K1 + K2)

    def step_forward(self, x: torch.tensor, t: torch.tensor) -> torch.tensor:
        """Euler-Maruyama."""
        dW = torch.sqrt(self.dt) * torch.randn_like(x)
        return x + self.bf(x, t) * self.dt + torch.sqrt(2 * self.eps) * dW

    def rollout_forward(self, init: torch.tensor, method: str = 'heun') -> torch.tensor:
        """Solve the forward-time SDE to generate a batch of samples."""
        save_every = int(self.n_step / self.n_save)
        xs = torch.zeros((self.n_save, *init.shape)).to(init.device)
        x = init
        self.dt = self.dt.to(init.device)

        save_counter = 0

        for ii, t in enumerate(self.ts[:-1]):
            t = t.to(init.device).unsqueeze(0)
            if method == 'heun':
                x = self.step_forward_heun(x, t)
            else:
                x = self.step_forward(x, t)

            if (ii + 1) % save_every == 0:
                xs[save_counter] = x
                save_counter += 1

        xs[save_counter] = x

        return xs


class SFromEta(torch.nn.Module):
    """Class for turning a noise model into a score model."""
    def __init__(
        self,
        eta,
        gamma,
    ) -> None:
        super(SFromEta, self).__init__()
        self.eta = eta
        self.gamma = gamma

    def forward(self, x, t):
        val = (self.eta(x,t) / self.gamma(t))
        return val

def grab(var):
    return var.detach().cpu().numpy()


# Functions and class for ODE sampling.
def compute_div(f,x,t):
    """Compute the divergence of f(x,t) with respect to x, assuming that x is batched. Assumes data is [bs, d]"""
    bs = x.shape[0]
    with torch.set_grad_enabled(True):
        x.requires_grad_(True)
        t.requires_grad_(True)
        f_val = f(x, t)
        divergence = 0.0
        for i in range(x.shape[1]):
            divergence += \
                    torch.autograd.grad(
                            f_val[:, i].sum(), x, create_graph=True
                        )[0][:, i]

    return divergence.view(bs)


class PFlowRHS(torch.nn.Module):
    def __init__(self, b, interpolant, sample_only=False):
        super(PFlowRHS, self).__init__()
        self.b = b
        self.interpolant = interpolant
        self.sample_only = sample_only


    def setup_rhs(self):
        def rhs(x: torch.tensor, t: torch.tensor):
            self.b.to(x)

            t = t.unsqueeze(0)
            return self.b(x,t)

        self.rhs = rhs


    def forward(self, t, states):
        x = states[0]
        if self.sample_only:
            return (self.rhs(x, t), torch.zeros(x.shape[0]).to(x))
        else:
            return (self.rhs(x, t), -compute_div(self.rhs, x, t))

    def reverse(self, t: torch.tensor, states):
        x = states[0]
        if self.sample_only:
            return (-self.rhs(x, t), torch.zeros(x.shape[0]).to(x))
        else:
            return (-self.rhs(x, t), compute_div(self.rhs, x, t))

from dataclasses import dataclass
Velocity = torch.nn.Module

@dataclass
class PFlowIntegrator:
    b: Velocity
    method: str
    interpolant: Interpolant
    start_end: tuple = (0.0, 1.0)
    n_step: int = 5
    atol: torch.tensor = 1e-5
    rtol: torch.tensor = 1e-5
    sample_only: bool  = False
    mirror:      bool  = False


    def __post_init__(self) -> None:

        self.rhs = PFlowRHS(b=self.b, interpolant=self.interpolant, sample_only=self.sample_only)
        self.rhs.setup_rhs()

        self.start, self.end = self.start_end[0], self.start_end[1]


    def rollout(self, x0, reverse=False):
        if reverse:
            integration_times = torch.linspace(self.end, self.start, self.n_step).to(x0)
        else:
            integration_times = torch.linspace(self.start, self.end, self.n_step).to(x0)
        dlogp = torch.zeros(x0.shape[0]).to(x0)

        state = odeint(
            self.rhs,
            (x0, dlogp),
            integration_times,
            method=self.method,
            atol=[self.atol, self.atol],
            rtol=[self.rtol, self.rtol]
        )

        x, dlogp = state
        return x, dlogp


def grab(var):
    return var.detach().cpu().numpy()

# %% [markdown]
# We now define our model. We choose a Unet with simple time-embedding and we added attention layer.

# %%
# Model inspired from the Unet in Denoising Diffusion Probabilistic Models : https://arxiv.org/abs/2006.11239 and then simplified by CNRS - Formation FIDLE.
# !pip install einops

import torch
from torch import nn, einsum
import torch.nn.functional as F
from inspect import isfunction
from functools import partial
import math
from einops import rearrange

def exists(x):
    return x is not None


def default(val, d):
    if exists(val):
        return val
    return d() if isfunction(d) else d


class Residual(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, *args, **kwargs):
        return self.fn(x, *args, **kwargs) + x


def Upsample(dim):
    return nn.ConvTranspose2d(dim, dim, 4, 2, 1)


def Downsample(dim):
    return nn.Conv2d(dim, dim, 4, 2, 1)


class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, time):
        device = time.device
        half_dim = self.dim // 2
        embeddings = math.log(10000) / (half_dim - 1)
        embeddings = torch.exp(torch.arange(half_dim, device=device) * -embeddings)
        embeddings = time[:, None] * embeddings[None, :]
        embeddings = torch.cat((embeddings.sin(), embeddings.cos()), dim=-1)
        return embeddings


class ConvNextBlock(nn.Module):
    """https://arxiv.org/abs/2201.03545"""

    def __init__(self, dim, dim_out, *, time_emb_dim=None, mult=2, norm=True):
        super().__init__()
        self.mlp = (
            nn.Sequential(nn.GELU(), nn.Linear(time_emb_dim, dim))
            if exists(time_emb_dim)
            else None
        )

        self.ds_conv = nn.Conv2d(dim, dim, 7, padding=3, groups=dim)

        self.net = nn.Sequential(
            nn.GroupNorm(1, dim) if norm else nn.Identity(),
            nn.Conv2d(dim, dim_out * mult, 3, padding=1),
            nn.GELU(),
            nn.GroupNorm(1, dim_out * mult),
            nn.Conv2d(dim_out * mult, dim_out, 3, padding=1),
        )

        self.res_conv = nn.Conv2d(dim, dim_out, 1) if dim != dim_out else nn.Identity()

    def forward(self, x, time_emb=None):
        h = self.ds_conv(x)

        if exists(self.mlp) and exists(time_emb):
            assert exists(time_emb), "time embedding must be passed in"
            condition = self.mlp(time_emb)
            h = h + rearrange(condition, "b c -> b c 1 1")

        h = self.net(h)
        return h + self.res_conv(x)


class Attention(nn.Module):
    def __init__(self, dim, heads=4, dim_head=32):
        super().__init__()
        self.scale = dim_head**-0.5
        self.heads = heads
        hidden_dim = dim_head * heads
        self.to_qkv = nn.Conv2d(dim, hidden_dim * 3, 1, bias=False)
        self.to_out = nn.Conv2d(hidden_dim, dim, 1)

    def forward(self, x):
        b, c, h, w = x.shape
        qkv = self.to_qkv(x).chunk(3, dim=1)
        q, k, v = map(
            lambda t: rearrange(t, "b (h c) x y -> b h c (x y)", h=self.heads), qkv
        )
        q = q * self.scale

        sim = einsum("b h d i, b h d j -> b h i j", q, k)
        sim = sim - sim.amax(dim=-1, keepdim=True).detach()
        attn = sim.softmax(dim=-1)

        out = einsum("b h i j, b h d j -> b h i d", attn, v)
        out = rearrange(out, "b h (x y) d -> b (h d) x y", x=h, y=w)
        return self.to_out(out)


class LinearAttention(nn.Module):
    def __init__(self, dim, heads=4, dim_head=32):
        super().__init__()
        self.scale = dim_head**-0.5
        self.heads = heads
        hidden_dim = dim_head * heads
        self.to_qkv = nn.Conv2d(dim, hidden_dim * 3, 1, bias=False)

        self.to_out = nn.Sequential(nn.Conv2d(hidden_dim, dim, 1),
                                    nn.GroupNorm(1, dim))

    def forward(self, x):
        b, c, h, w = x.shape
        qkv = self.to_qkv(x).chunk(3, dim=1)
        q, k, v = map(
            lambda t: rearrange(t, "b (h c) x y -> b h c (x y)", h=self.heads), qkv
        )

        q = q.softmax(dim=-2)
        k = k.softmax(dim=-1)

        q = q * self.scale
        context = torch.einsum("b h d n, b h e n -> b h d e", k, v)

        out = torch.einsum("b h d e, b h d n -> b h e n", context, q)
        out = rearrange(out, "b h c (x y) -> b (h c) x y", h=self.heads, x=h, y=w)
        return self.to_out(out)


class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.fn = fn
        self.norm = nn.GroupNorm(1, dim)

    def forward(self, x):
        x = self.norm(x)
        return self.fn(x)


class Unet(nn.Module):
    def __init__(
        self,
        dim,
        init_dim=None,
        out_dim=None,
        dim_mults=(1, 2, 3,4),
        channels=3,
        with_time_emb=True,
        convnext_mult=2,
    ):
        super().__init__()

        # determine dimensions
        self.channels = channels

        init_dim = default(init_dim, dim // 3 * 2)
        self.init_conv = nn.Conv2d(channels, init_dim, 7, padding=3)

        dims = [init_dim, *map(lambda m: dim * m, dim_mults)]
        in_out = list(zip(dims[:-1], dims[1:]))

        block_klass = partial(ConvNextBlock, mult=convnext_mult)

        # time embeddings
        if with_time_emb:
            time_dim = dim * 4
            self.time_mlp = nn.Sequential(
                SinusoidalPositionEmbeddings(dim),
                nn.Linear(dim, time_dim),
                nn.GELU(),
                nn.Linear(time_dim, time_dim),
            )
        else:
            time_dim = None
            self.time_mlp = None

        # layers
        self.downs = nn.ModuleList([])
        self.ups = nn.ModuleList([])
        num_resolutions = len(in_out)

        for ind, (dim_in, dim_out) in enumerate(in_out):
            is_last = ind >= (num_resolutions - 1)

            self.downs.append(
                nn.ModuleList(
                    [
                        block_klass(dim_in, dim_out, time_emb_dim=time_dim),
                        block_klass(dim_out, dim_out, time_emb_dim=time_dim),
                        Residual(PreNorm(dim_out, LinearAttention(dim_out))),
                        Downsample(dim_out) if not is_last else nn.Identity(),
                    ]
                )
            )

        mid_dim = dims[-1]
        self.mid_block1 = block_klass(mid_dim, mid_dim, time_emb_dim=time_dim)
        self.mid_attn = Residual(PreNorm(mid_dim, Attention(mid_dim)))
        self.mid_block2 = block_klass(mid_dim, mid_dim, time_emb_dim=time_dim)

        for ind, (dim_in, dim_out) in enumerate(reversed(in_out[1:])):
            is_last = ind >= (num_resolutions - 1)

            self.ups.append(
                nn.ModuleList(
                    [
                        block_klass(dim_out * 2, dim_in, time_emb_dim=time_dim),
                        block_klass(dim_in, dim_in, time_emb_dim=time_dim),
                        Residual(PreNorm(dim_in, LinearAttention(dim_in))),
                        Upsample(dim_in) if not is_last else nn.Identity(),
                    ]
                )
            )

        out_dim = default(out_dim, channels)
        self.final_conv = nn.Sequential(
            block_klass(dim, dim), nn.Conv2d(dim, out_dim, 1)
        )

    def forward(self, x, time):
        x = self.init_conv(x)

        t = self.time_mlp(time) if exists(self.time_mlp) else None

        h = []

        # downsample
        for block1, block2, attn, downsample in self.downs:
            x = block1(x, t)
            x = block2(x, t)
            x = attn(x)
            h.append(x)
            x = downsample(x)

        # bottleneck
        x = self.mid_block1(x, t)
        x = self.mid_attn(x)
        x = self.mid_block2(x, t)

        # upsample
        for block1, block2, attn, upsample in self.ups:
            x = torch.cat((x, h.pop()), dim=1)
            x = block1(x, t)
            x = block2(x, t)
            x = attn(x)
            x = upsample(x)

        return self.final_conv(x)
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)

# %% [markdown]
# Now, you need to drag the flowers.zip file in the folder in google colab and then you just have to unzip the file.

# %%
# !unzip flowers_64
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: flowers_64/flowers/image_03190.jpg
#   inflating: flowers_64/flowers/image_03191.jpg
#   inflating: flowers_64/flowers/image_03192.jpg
#   inflating: flowers_64/flowers/image_03193.jpg
#   inflating: flowers_64/flowers/image_03194.jpg
#   inflating: flowers_64/flowers/image_03195.jpg
#   inflating: flowers_64/flowers/image_03196.jpg
#   inflating: flowers_64/flowers/image_03197.jpg
#   inflating: flowers_64/flowers/image_03198.jpg
#   inflating: flowers_64/flowers/image_03199.jpg
#   inflating: flowers_64/flowers/image_03200.jpg
#   inflating: flowers_64/flowers/image_03201.jpg
#   inflating: flowers_64/flowers/image_03202.jpg
#   inflating: flowers_64/flowers/image_03203.jpg
#   inflating: flowers_64/flowers/image_03204.jpg
#   inflating: flowers_64/flowers/image_03205.jpg
#   inflating: flowers_64/flowers/image_03206.jpg
#   inflating: flowers_64/flowers/image_03207.jpg
#   inflating: flowers_64/flowers/image_03208.jpg
#   inflating: flowers_64/flowers/image_03209.jpg
#   inflating: flowers_64/flowers/image_03210.jpg
#   inflating: flowers_64/flowers/image_03211.jpg
#   inflating: flowers_64/flowers/image_03212.jpg
#   inflating: flowers_64/flowers/image_03213.jpg
#   inflating: flowers_64/flowers/image_03214.jpg
#   inflating: flowers_64/flowers/image_03215.jpg
#   inflating: flowers_64/flowers/image_03216.jpg
#   inflating: flowers_64/flowers/image_03217.jpg
#   inflating: flowers_64/flowers/image_03218.jpg
#   inflating: flowers_64/flowers/image_03219.jpg
#   inflating: flowers_64/flowers/image_03220.jpg
#   inflating: flowers_64/flowers/image_03221.jpg
#   inflating: flowers_64/flowers/image_03222.jpg
#   inflating: flowers_64/flowers/image_03223.jpg
#   inflating: flowers_64/flowers/image_03224.jpg
#   inflating: flowers_64/flowers/image_03225.jpg
#   inflating: flowers_64/flowers/image_03226.jpg
#   inflating: flowers_64/flowers/image_03227.jpg
#   inflating: flowers_64/flowers/image_03228.jpg
#   inflating: flowers_64/flowers/image_03229.jpg
#   inflating: flowers_64/flowers/image_03230.jpg
#   inflating: flowers_64/flowers/image_03231.jpg
#   inflating: flowers_64/flowers/image_03232.jpg
#   inflating: flowers_64/flowers/image_03233.jpg
#   inflating: flowers_64/flowers/image_03234.jpg
#   inflating: flowers_64/flowers/image_03235.jpg
#   inflating: flowers_64/flowers/image_03236.jpg
#   inflating: flowers_64/flowers/image_03237.jpg
#   inflating: flowers_64/flowers/image_03238.jpg
#   inflating: flowers_64/flowers/image_03239.jpg
#   inflating: flowers_64/flowers/image_03240.jpg
#   inflating: flowers_64/flowers/image_03241.jpg
#   inflating: flowers_64/flowers/image_03242.jpg
#   inflating: flowers_64/flowers/image_03243.jpg
#   inflating: flowers_64/flowers/image_03244.jpg
#   inflating: flowers_64/flowers/image_03245.jpg
#   inflating: flowers_64/flowers/image_03246.jpg
#   inflating: flowers_64/flowers/image_03247.jpg
#   inflating: flowers_64/flowers/image_03248.jpg
#   inflating: flowers_64/flowers/image_03249.jpg
#   inflating: flowers_64/flowers/image_03250.jpg
#   inflating: flowers_64/flowers/image_03251.jpg
#   inflating: flowers_64/flowers/image_03252.jpg
#   inflating: flowers_64/flowers/image_03253.jpg
#   inflating: flowers_64/flowers/image_03254.jpg
#   inflating: flowers_64/flowers/image_03255.jpg
#   inflating: flowers_64/flowers/image_03256.jpg
#   inflating: flowers_64/flowers/image_03257.jpg
#   inflating: flowers_64/flowers/image_03258.jpg
#   inflating: flowers_64/flowers/image_03259.jpg
#   inflating: flowers_64/flowers/image_03260.jpg
#   inflating: flowers_64/flowers/image_03261.jpg
#   inflating: flowers_64/flowers/image_03262.jpg
#   inflating: flowers_64/flowers/image_03263.jpg
#   inflating: flowers_64/flowers/image_03264.jpg
#   inflating: flowers_64/flowers/image_03265.jpg
#   inflating: flowers_64/flowers/image_03266.jpg
#   inflating: flowers_64/flowers/image_03267.jpg
#   inflating: flowers_64/flowers/image_03268.jpg
#   inflating: flowers_64/flowers/image_03269.jpg
#   inflating: flowers_64/flowers/image_03270.jpg
#   inflating: flowers_64/flowers/image_03271.jpg
#   inflating: flowers_64/flowers/image_03272.jpg
#   inflating: flowers_64/flowers/image_03273.jpg
#   inflating: flowers_64/flowers/image_03274.jpg
#   inflating: flowers_64/flowers/image_03275.jpg
#   inflating: flowers_64/flowers/image_03276.jpg
#   inflating: flowers_64/flowers/image_03277.jpg
#   inflating: flowers_64/flowers/image_03278.jpg
#   inflating: flowers_64/flowers/image_03279.jpg
#   inflating: flowers_64/flowers/image_03280.jpg
#   inflating: flowers_64/flowers/image_03281.jpg
#   inflating: flowers_64/flowers/image_03282.jpg
#   inflating: flowers_64/flowers/image_03283.jpg
#   inflating: flowers_64/flowers/image_03284.jpg
#   inflating: flowers_64/flowers/image_03285.jpg
#   inflating: flowers_64/flowers/image_03286.jpg
#   inflating: flowers_64/flowers/image_03287.jpg
#   inflating: flowers_64/flowers/image_03288.jpg
#   inflating: flowers_64/flowers/image_03289.jpg
#   inflating: flowers_64/flowers/image_03290.jpg
#   inflating: flowers_64/flowers/image_03291.jpg
#   inflating: flowers_64/flowers/image_03292.jpg
#   inflating: flowers_64/flowers/image_03293.jpg
#   inflating: flowers_64/flowers/image_03294.jpg
#   inflating: flowers_64/flowers/image_03295.jpg
#   inflating: flowers_64/flowers/image_03296.jpg
#   inflating: flowers_64/flowers/image_03297.jpg
#   inflating: flowers_64/flowers/image_03298.jpg
#   inflating: flowers_64/flowers/image_03299.jpg
#   inflating: flowers_64/flowers/image_03300.jpg
#   inflating: flowers_64/flowers/image_03301.jpg
#   inflating: flowers_64/flowers/image_03302.jpg
#   inflating: flowers_64/flowers/image_03303.jpg
#   inflating: flowers_64/flowers/image_03304.jpg
#   inflating: flowers_64/flowers/image_03305.jpg
#   inflating: flowers_64/flowers/image_03306.jpg
#   inflating: flowers_64/flowers/image_03307.jpg
#   inflating: flowers_64/flowers/image_03308.jpg
#   inflating: flowers_64/flowers/image_03309.jpg
#   inflating: flowers_64/flowers/image_03310.jpg
#   inflating: flowers_64/flowers/image_03311.jpg
#   inflating: flowers_64/flowers/image_03312.jpg
#   inflating: flowers_64/flowers/image_03313.jpg
#   inflating: flowers_64/flowers/image_03314.jpg
#   inflating: flowers_64/flowers/image_03315.jpg
#   inflating: flowers_64/flowers/image_03316.jpg
#   inflating: flowers_64/flowers/image_03317.jpg
#   inflating: flowers_64/flowers/image_03318.jpg
#   inflating: flowers_64/flowers/image_03319.jpg
#   inflating: flowers_64/flowers/image_03320.jpg
#   inflating: flowers_64/flowers/image_03321.jpg
#   inflating: flowers_64/flowers/image_03322.jpg
#   inflating: flowers_64/flowers/image_03323.jpg
#   inflating: flowers_64/flowers/image_03324.jpg
#   inflating: flowers_64/flowers/image_03325.jpg
#   inflating: flowers_64/flowers/image_03326.jpg
#   inflating: flowers_64/flowers/image_03327.jpg
#   inflating: flowers_64/flowers/image_03328.jpg
#   inflating: flowers_64/flowers/image_03329.jpg
#   inflating: flowers_64/flowers/image_03330.jpg
#   inflating: flowers_64/flowers/image_03331.jpg
#   inflating: flowers_64/flowers/image_03332.jpg
#   inflating: flowers_64/flowers/image_03333.jpg
#   inflating: flowers_64/flowers/image_03334.jpg
#   inflating: flowers_64/flowers/image_03335.jpg
#   inflating: flowers_64/flowers/image_03336.jpg
#   inflating: flowers_64/flowers/image_03337.jpg
#   inflating: flowers_64/flowers/image_03338.jpg
#   inflating: flowers_64/flowers/image_03339.jpg
#   inflating: flowers_64/flowers/image_03340.jpg
#   inflating: flowers_64/flowers/image_03341.jpg
#   inflating: flowers_64/flowers/image_03342.jpg
#   inflating: flowers_64/flowers/image_03343.jpg
#   inflating: flowers_64/flowers/image_03344.jpg
#   inflating: flowers_64/flowers/image_03345.jpg
#   inflating: flowers_64/flowers/image_03346.jpg
#   inflating: flowers_64/flowers/image_03347.jpg
#   inflating: flowers_64/flowers/image_03348.jpg
#   inflating: flowers_64/flowers/image_03349.jpg
#   inflating: flowers_64/flowers/image_03350.jpg
#   inflating: flowers_64/flowers/image_03351.jpg
#   inflating: flowers_64/flowers/image_03352.jpg
#   inflating: flowers_64/flowers/image_03353.jpg
#   inflating: flowers_64/flowers/image_03354.jpg
#   inflating: flowers_64/flowers/image_03355.jpg
#   inflating: flowers_64/flowers/image_03356.jpg
#   inflating: flowers_64/flowers/image_03357.jpg
#   inflating: flowers_64/flowers/image_03358.jpg
#   inflating: flowers_64/flowers/image_03359.jpg
#   inflating: flowers_64/flowers/image_03360.jpg
#   inflating: flowers_64/flowers/image_03361.jpg
#   inflating: flowers_64/flowers/image_03362.jpg
#   inflating: flowers_64/flowers/image_03363.jpg
#   inflating: flowers_64/flowers/image_03364.jpg
#   inflating: flowers_64/flowers/image_03365.jpg
#   inflating: flowers_64/flowers/image_03366.jpg
#   inflating: flowers_64/flowers/image_03367.jpg
#   inflating: flowers_64/flowers/image_03368.jpg
#   inflating: flowers_64/flowers/image_03369.jpg
#   inflating: flowers_64/flowers/image_03370.jpg
#   inflating: flowers_64/flowers/image_03371.jpg
#   inflating: flowers_64/flowers/image_03372.jpg
#   inflating: flowers_64/flowers/image_03373.jpg
#   inflating: flowers_64/flowers/image_03374.jpg
#   inflating: flowers_64/flowers/image_03375.jpg
#   inflating: flowers_64/flowers/image_03376.jpg
#   inflating: flowers_64/flowers/image_03377.jpg
#   inflating: flowers_64/flowers/image_03378.jpg
#   inflating: flowers_64/flowers/image_03379.jpg
#   inflating: flowers_64/flowers/image_03380.jpg
#   inflating: flowers_64/flowers/image_03381.jpg
#   inflating: flowers_64/flowers/image_03382.jpg
#   inflating: flowers_64/flowers/image_03383.jpg
#   inflating: flowers_64/flowers/image_03384.jpg
#   inflating: flowers_64/flowers/image_03385.jpg
#   inflating: flowers_64/flowers/image_03386.jpg
#   inflating: flowers_64/flowers/image_03387.jpg
#   inflating: flowers_64/flowers/image_03388.jpg
#   inflating: flowers_64/flowers/image_03389.jpg
#   inflating: flowers_64/flowers/image_03390.jpg
#   inflating: flowers_64/flowers/image_03391.jpg
#   inflating: flowers_64/flowers/image_03392.jpg
#   inflating: flowers_64/flowers/image_03393.jpg
#   inflating: flowers_64/flowers/image_03394.jpg
#   inflating: flowers_64/flowers/image_03395.jpg
#   inflating: flowers_64/flowers/image_03396.jpg
#   inflating: flowers_64/flowers/image_03397.jpg
#   inflating: flowers_64/flowers/image_03398.jpg
#   inflating: flowers_64/flowers/image_03399.jpg
#   inflating: flowers_64/flowers/image_03400.jpg
#   inflating: flowers_64/flowers/image_03401.jpg
#   inflating: flowers_64/flowers/image_03402.jpg
#   inflating: flowers_64/flowers/image_03403.jpg
#   inflating: flowers_64/flowers/image_03404.jpg
#   inflating: flowers_64/flowers/image_03405.jpg
#   inflating: flowers_64/flowers/image_03406.jpg
#   inflating: flowers_64/flowers/image_03407.jpg
#   inflating: flowers_64/flowers/image_03408.jpg
#   inflating: flowers_64/flowers/image_03409.jpg
#   inflating: flowers_64/flowers/image_03410.jpg
#   inflating: flowers_64/flowers/image_03411.jpg
#   inflating: flowers_64/flowers/image_03412.jpg
#   inflating: flowers_64/flowers/image_03413.jpg
#   inflating: flowers_64/flowers/image_03414.jpg
#   inflating: flowers_64/flowers/image_03415.jpg
#   inflating: flowers_64/flowers/image_03416.jpg
#   inflating: flowers_64/flowers/image_03417.jpg
#   inflating: flowers_64/flowers/image_03418.jpg
#   inflating: flowers_64/flowers/image_03419.jpg
#   inflating: flowers_64/flowers/image_03420.jpg
#   inflating: flowers_64/flowers/image_03421.jpg
#   inflating: flowers_64/flowers/image_03422.jpg
#   inflating: flowers_64/flowers/image_03423.jpg
#   inflating: flowers_64/flowers/image_03424.jpg
#   inflating: flowers_64/flowers/image_03425.jpg
#   inflating: flowers_64/flowers/image_03426.jpg
#   inflating: flowers_64/flowers/image_03427.jpg
#   inflating: flowers_64/flowers/image_03428.jpg
#   inflating: flowers_64/flowers/image_03429.jpg
#   inflating: flowers_64/flowers/image_03430.jpg
#   inflating: flowers_64/flowers/image_03431.jpg
#   inflating: flowers_64/flowers/image_03432.jpg
#   inflating: flowers_64/flowers/image_03433.jpg
#   inflating: flowers_64/flowers/image_03434.jpg
#   inflating: flowers_64/flowers/image_03435.jpg
#   inflating: flowers_64/flowers/image_03436.jpg
#   inflating: flowers_64/flowers/image_03437.jpg
#   inflating: flowers_64/flowers/image_03438.jpg
#   inflating: flowers_64/flowers/image_03439.jpg
#   inflating: flowers_64/flowers/image_03440.jpg
#   inflating: flowers_64/flowers/image_03441.jpg
#   inflating: flowers_64/flowers/image_03442.jpg
#   inflating: flowers_64/flowers/image_03443.jpg
#   inflating: flowers_64/flowers/image_03444.jpg
#   inflating: flowers_64/flowers/image_03445.jpg
#   inflating: flowers_64/flowers/image_03446.jpg
#   inflating: flowers_64/flowers/image_03447.jpg
#   inflating: flowers_64/flowers/image_03448.jpg
#   inflating: flowers_64/flowers/image_03449.jpg
#   inflating: flowers_64/flowers/image_03450.jpg
#   inflating: flowers_64/flowers/image_03451.jpg
#   inflating: flowers_64/flowers/image_03452.jpg
#   inflating: flowers_64/flowers/image_03453.jpg
#   inflating: flowers_64/flowers/image_03454.jpg
#   inflating: flowers_64/flowers/image_03455.jpg
#   inflating: flowers_64/flowers/image_03456.jpg
#   inflating: flowers_64/flowers/image_03457.jpg
#   inflating: flowers_64/flowers/image_03458.jpg
#   inflating: flowers_64/flowers/image_03459.jpg
#   inflating: flowers_64/flowers/image_03460.jpg
#   inflating: flowers_64/flowers/image_03461.jpg
#   inflating: flowers_64/flowers/image_03462.jpg
#   inflating: flowers_64/flowers/image_03463.jpg
#   inflating: flowers_64/flowers/image_03464.jpg
#   inflating: flowers_64/flowers/image_03465.jpg
#   inflating: flowers_64/flowers/image_03466.jpg
#   inflating: flowers_64/flowers/image_03467.jpg
#   inflating: flowers_64/flowers/image_03468.jpg
#   inflating: flowers_64/flowers/image_03469.jpg
#   inflating: flowers_64/flowers/image_03470.jpg
#   inflating: flowers_64/flowers/image_03471.jpg
#   inflating: flowers_64/flowers/image_03472.jpg
#   inflating: flowers_64/flowers/image_03473.jpg
#   inflating: flowers_64/flowers/image_03474.jpg
#   inflating: flowers_64/flowers/image_03475.jpg
#   inflating: flowers_64/flowers/image_03476.jpg
#   inflating: flowers_64/flowers/image_03477.jpg
#   inflating: flowers_64/flowers/image_03478.jpg
#   inflating: flowers_64/flowers/image_03479.jpg
#   inflating: flowers_64/flowers/image_03480.jpg
#   inflating: flowers_64/flowers/image_03481.jpg
#   inflating: flowers_64/flowers/image_03482.jpg
#   inflating: flowers_64/flowers/image_03483.jpg
#   inflating: flowers_64/flowers/image_03484.jpg
#   inflating: flowers_64/flowers/image_03485.jpg
#   inflating: flowers_64/flowers/image_03486.jpg
#   inflating: flowers_64/flowers/image_03487.jpg
#   inflating: flowers_64/flowers/image_03488.jpg
#   inflating: flowers_64/flowers/image_03489.jpg
#   inflating: flowers_64/flowers/image_03490.jpg
#   inflating: flowers_64/flowers/image_03491.jpg
#   inflating: flowers_64/flowers/image_03492.jpg
#   inflating: flowers_64/flowers/image_03493.jpg
#   inflating: flowers_64/flowers/image_03494.jpg
#   inflating: flowers_64/flowers/image_03495.jpg
#   inflating: flowers_64/flowers/image_03496.jpg
#   inflating: flowers_64/flowers/image_03497.jpg
#   inflating: flowers_64/flowers/image_03498.jpg
#   inflating: flowers_64/flowers/image_03499.jpg
#   inflating: flowers_64/flowers/image_03500.jpg
#   inflating: flowers_64/flowers/image_03501.jpg
#   inflating: flowers_64/flowers/image_03502.jpg
#   inflating: flowers_64/flowers/image_03503.jpg
#   inflating: flowers_64/flowers/image_03504.jpg
#   inflating: flowers_64/flowers/image_03505.jpg
#   inflating: flowers_64/flowers/image_03506.jpg
#   inflating: flowers_64/flowers/image_03507.jpg
#   inflating: flowers_64/flowers/image_03508.jpg
#   inflating: flowers_64/flowers/image_03509.jpg
#   inflating: flowers_64/flowers/image_03510.jpg
#   inflating: flowers_64/flowers/image_03511.jpg
#   inflating: flowers_64/flowers/image_03512.jpg
#   inflating: flowers_64/flowers/image_03513.jpg
#   inflating: flowers_64/flowers/image_03514.jpg
#   inflating: flowers_64/flowers/image_03515.jpg
#   inflating: flowers_64/flowers/image_03516.jpg
#   inflating: flowers_64/flowers/image_03517.jpg
#   inflating: flowers_64/flowers/image_03518.jpg
#   inflating: flowers_64/flowers/image_03519.jpg
#   inflating: flowers_64/flowers/image_03520.jpg
#   inflating: flowers_64/flowers/image_03521.jpg
#   inflating: flowers_64/flowers/image_03522.jpg
#   inflating: flowers_64/flowers/image_03523.jpg
#   inflating: flowers_64/flowers/image_03524.jpg
#   inflating: flowers_64/flowers/image_03525.jpg
#   inflating: flowers_64/flowers/image_03526.jpg
#   inflating: flowers_64/flowers/image_03527.jpg
#   inflating: flowers_64/flowers/image_03528.jpg
#   inflating: flowers_64/flowers/image_03529.jpg
#   inflating: flowers_64/flowers/image_03530.jpg
#   inflating: flowers_64/flowers/image_03531.jpg
#   inflating: flowers_64/flowers/image_03532.jpg
#   inflating: flowers_64/flowers/image_03533.jpg
#   inflating: flowers_64/flowers/image_03534.jpg
#   inflating: flowers_64/flowers/image_03535.jpg
#   inflating: flowers_64/flowers/image_03536.jpg
#   inflating: flowers_64/flowers/image_03537.jpg
#   inflating: flowers_64/flowers/image_03538.jpg
#   inflating: flowers_64/flowers/image_03539.jpg
#   inflating: flowers_64/flowers/image_03540.jpg
#   inflating: flowers_64/flowers/image_03541.jpg
#   inflating: flowers_64/flowers/image_03542.jpg
#   inflating: flowers_64/flowers/image_03543.jpg
#   inflating: flowers_64/flowers/image_03544.jpg
#   inflating: flowers_64/flowers/image_03545.jpg
#   inflating: flowers_64/flowers/image_03546.jpg
#   inflating: flowers_64/flowers/image_03547.jpg
#   inflating: flowers_64/flowers/image_03548.jpg
#   inflating: flowers_64/flowers/image_03549.jpg
#   inflating: flowers_64/flowers/image_03550.jpg
#   inflating: flowers_64/flowers/image_03551.jpg
#   inflating: flowers_64/flowers/image_03552.jpg
#   inflating: flowers_64/flowers/image_03553.jpg
#   inflating: flowers_64/flowers/image_03554.jpg
#   inflating: flowers_64/flowers/image_03555.jpg
#   inflating: flowers_64/flowers/image_03556.jpg
#   inflating: flowers_64/flowers/image_03557.jpg
#   inflating: flowers_64/flowers/image_03558.jpg
#   inflating: flowers_64/flowers/image_03559.jpg
#   inflating: flowers_64/flowers/image_03560.jpg
#   inflating: flowers_64/flowers/image_03561.jpg
#   inflating: flowers_64/flowers/image_03562.jpg
#   inflating: flowers_64/flowers/image_03563.jpg
#   inflating: flowers_64/flowers/image_03564.jpg
#   inflating: flowers_64/flowers/image_03565.jpg
#   inflating: flowers_64/flowers/image_03566.jpg
#   inflating: flowers_64/flowers/image_03567.jpg
#   inflating: flowers_64/flowers/image_03568.jpg
#   inflating: flowers_64/flowers/image_03569.jpg
#   inflating: flowers_64/flowers/image_03570.jpg
#   inflating: flowers_64/flowers/image_03571.jpg
#   inflating: flowers_64/flowers/image_03572.jpg
#   inflating: flowers_64/flowers/image_03573.jpg
#   inflating: flowers_64/flowers/image_03574.jpg
#   inflating: flowers_64/flowers/image_03575.jpg
#   inflating: flowers_64/flowers/image_03576.jpg
#   inflating: flowers_64/flowers/image_03577.jpg
#   inflating: flowers_64/flowers/image_03578.jpg
#   inflating: flowers_64/flowers/image_03579.jpg
#   inflating: flowers_64/flowers/image_03580.jpg
#   inflating: flowers_64/flowers/image_03581.jpg
#   inflating: flowers_64/flowers/image_03582.jpg
#   inflating: flowers_64/flowers/image_03583.jpg
#   inflating: flowers_64/flowers/image_03584.jpg
#   inflating: flowers_64/flowers/image_03585.jpg
#   inflating: flowers_64/flowers/image_03586.jpg
#   inflating: flowers_64/flowers/image_03587.jpg
#   inflating: flowers_64/flowers/image_03588.jpg
#   inflating: flowers_64/flowers/image_03589.jpg
#   inflating: flowers_64/flowers/image_03590.jpg
#   inflating: flowers_64/flowers/image_03591.jpg
#   inflating: flowers_64/flowers/image_03592.jpg
#   inflating: flowers_64/flowers/image_03593.jpg
#   inflating: flowers_64/flowers/image_03594.jpg
#   inflating: flowers_64/flowers/image_03595.jpg
#   inflating: flowers_64/flowers/image_03596.jpg
#   inflating: flowers_64/flowers/image_03597.jpg
#   inflating: flowers_64/flowers/image_03598.jpg
#   inflating: flowers_64/flowers/image_03599.jpg
#   inflating: flowers_64/flowers/image_03600.jpg
#   inflating: flowers_64/flowers/image_03601.jpg
#   inflating: flowers_64/flowers/image_03602.jpg
#   inflating: flowers_64/flowers/image_03603.jpg
#   inflating: flowers_64/flowers/image_03604.jpg
#   inflating: flowers_64/flowers/image_03605.jpg
#   inflating: flowers_64/flowers/image_03606.jpg
#   inflating: flowers_64/flowers/image_03607.jpg
#   inflating: flowers_64/flowers/image_03608.jpg
#   inflating: flowers_64/flowers/image_03609.jpg
#   inflating: flowers_64/flowers/image_03610.jpg
#   inflating: flowers_64/flowers/image_03611.jpg
#   inflating: flowers_64/flowers/image_03612.jpg
#   inflating: flowers_64/flowers/image_03613.jpg
#   inflating: flowers_64/flowers/image_03614.jpg
#   inflating: flowers_64/flowers/image_03615.jpg
#   inflating: flowers_64/flowers/image_03616.jpg
#   inflating: flowers_64/flowers/image_03617.jpg
#   inflating: flowers_64/flowers/image_03618.jpg
#   inflating: flowers_64/flowers/image_03619.jpg
#   inflating: flowers_64/flowers/image_03620.jpg
#   inflating: flowers_64/flowers/image_03621.jpg
#   inflating: flowers_64/flowers/image_03622.jpg
#   inflating: flowers_64/flowers/image_03623.jpg
#   inflating: flowers_64/flowers/image_03624.jpg
#   inflating: flowers_64/flowers/image_03625.jpg
#   inflating: flowers_64/flowers/image_03626.jpg
#   inflating: flowers_64/flowers/image_03627.jpg
#   inflating: flowers_64/flowers/image_03628.jpg
#   inflating: flowers_64/flowers/image_03629.jpg
#   inflating: flowers_64/flowers/image_03630.jpg
#   inflating: flowers_64/flowers/image_03631.jpg
#   inflating: flowers_64/flowers/image_03632.jpg
#   inflating: flowers_64/flowers/image_03633.jpg
#   inflating: flowers_64/flowers/image_03634.jpg
#   inflating: flowers_64/flowers/image_03635.jpg
#   inflating: flowers_64/flowers/image_03636.jpg
#   inflating: flowers_64/flowers/image_03637.jpg
#   inflating: flowers_64/flowers/image_03638.jpg
#   inflating: flowers_64/flowers/image_03639.jpg
#   inflating: flowers_64/flowers/image_03640.jpg
#   inflating: flowers_64/flowers/image_03641.jpg
#   inflating: flowers_64/flowers/image_03642.jpg
#   inflating: flowers_64/flowers/image_03643.jpg
#   inflating: flowers_64/flowers/image_03644.jpg
#   inflating: flowers_64/flowers/image_03645.jpg
#   inflating: flowers_64/flowers/image_03646.jpg
#   inflating: flowers_64/flowers/image_03647.jpg
#   inflating: flowers_64/flowers/image_03648.jpg
#   inflating: flowers_64/flowers/image_03649.jpg
#   inflating: flowers_64/flowers/image_03650.jpg
#   inflating: flowers_64/flowers/image_03651.jpg
#   inflating: flowers_64/flowers/image_03652.jpg
#   inflating: flowers_64/flowers/image_03653.jpg
#   inflating: flowers_64/flowers/image_03654.jpg
#   inflating: flowers_64/flowers/image_03655.jpg
#   inflating: flowers_64/flowers/image_03656.jpg
#   inflating: flowers_64/flowers/image_03657.jpg
#   inflating: flowers_64/flowers/image_03658.jpg
#   inflating: flowers_64/flowers/image_03659.jpg
#   inflating: flowers_64/flowers/image_03660.jpg
#   inflating: flowers_64/flowers/image_03661.jpg
#   inflating: flowers_64/flowers/image_03662.jpg
#   inflating: flowers_64/flowers/image_03663.jpg
#   inflating: flowers_64/flowers/image_03664.jpg
#   inflating: flowers_64/flowers/image_03665.jpg
#   inflating: flowers_64/flowers/image_03666.jpg
#   inflating: flowers_64/flowers/image_03667.jpg
#   inflating: flowers_64/flowers/image_03668.jpg
#   inflating: flowers_64/flowers/image_03669.jpg
#   inflating: flowers_64/flowers/image_03670.jpg
#   inflating: flowers_64/flowers/image_03671.jpg
#   inflating: flowers_64/flowers/image_03672.jpg
#   inflating: flowers_64/flowers/image_03673.jpg
#   inflating: flowers_64/flowers/image_03674.jpg
#   inflating: flowers_64/flowers/image_03675.jpg
#   inflating: flowers_64/flowers/image_03676.jpg
#   inflating: flowers_64/flowers/image_03677.jpg
#   inflating: flowers_64/flowers/image_03678.jpg
#   inflating: flowers_64/flowers/image_03679.jpg
#   inflating: flowers_64/flowers/image_03680.jpg
#   inflating: flowers_64/flowers/image_03681.jpg
#   inflating: flowers_64/flowers/image_03682.jpg
#   inflating: flowers_64/flowers/image_03683.jpg
#   inflating: flowers_64/flowers/image_03684.jpg
#   inflating: flowers_64/flowers/image_03685.jpg
#   inflating: flowers_64/flowers/image_03686.jpg
#   inflating: flowers_64/flowers/image_03687.jpg
#   inflating: flowers_64/flowers/image_03688.jpg
#   inflating: flowers_64/flowers/image_03689.jpg
#   inflating: flowers_64/flowers/image_03690.jpg
#   inflating: flowers_64/flowers/image_03691.jpg
#   inflating: flowers_64/flowers/image_03692.jpg
#   inflating: flowers_64/flowers/image_03693.jpg
#   inflating: flowers_64/flowers/image_03694.jpg
#   inflating: flowers_64/flowers/image_03695.jpg
#   inflating: flowers_64/flowers/image_03696.jpg
#   inflating: flowers_64/flowers/image_03697.jpg
#   inflating: flowers_64/flowers/image_03698.jpg
#   inflating: flowers_64/flowers/image_03699.jpg
#   inflating: flowers_64/flowers/image_03700.jpg
#   inflating: flowers_64/flowers/image_03701.jpg
#   inflating: flowers_64/flowers/image_03702.jpg
#   inflating: flowers_64/flowers/image_03703.jpg
#   inflating: flowers_64/flowers/image_03704.jpg
#   inflating: flowers_64/flowers/image_03705.jpg
#   inflating: flowers_64/flowers/image_03706.jpg
#   inflating: flowers_64/flowers/image_03707.jpg
#   inflating: flowers_64/flowers/image_03708.jpg
#   inflating: flowers_64/flowers/image_03709.jpg
#   inflating: flowers_64/flowers/image_03710.jpg
#   inflating: flowers_64/flowers/image_03711.jpg
#   inflating: flowers_64/flowers/image_03712.jpg
#   inflating: flowers_64/flowers/image_03713.jpg
#   inflating: flowers_64/flowers/image_03714.jpg
#   inflating: flowers_64/flowers/image_03715.jpg
#   inflating: flowers_64/flowers/image_03716.jpg
#   inflating: flowers_64/flowers/image_03717.jpg
#   inflating: flowers_64/flowers/image_03718.jpg
#   inflating: flowers_64/flowers/image_03719.jpg
#   inflating: flowers_64/flowers/image_03720.jpg
#   inflating: flowers_64/flowers/image_03721.jpg
#   inflating: flowers_64/flowers/image_03722.jpg
#   inflating: flowers_64/flowers/image_03723.jpg
#   inflating: flowers_64/flowers/image_03724.jpg
#   inflating: flowers_64/flowers/image_03725.jpg
#   inflating: flowers_64/flowers/image_03726.jpg
#   inflating: flowers_64/flowers/image_03727.jpg
#   inflating: flowers_64/flowers/image_03728.jpg
#   inflating: flowers_64/flowers/image_03729.jpg
#   inflating: flowers_64/flowers/image_03730.jpg
#   inflating: flowers_64/flowers/image_03731.jpg
#   inflating: flowers_64/flowers/image_03732.jpg
#   inflating: flowers_64/flowers/image_03733.jpg
#   inflating: flowers_64/flowers/image_03734.jpg
#   inflating: flowers_64/flowers/image_03735.jpg
#   inflating: flowers_64/flowers/image_03736.jpg
#   inflating: flowers_64/flowers/image_03737.jpg
#   inflating: flowers_64/flowers/image_03738.jpg
#   inflating: flowers_64/flowers/image_03739.jpg
#   inflating: flowers_64/flowers/image_03740.jpg
#   inflating: flowers_64/flowers/image_03741.jpg
#   inflating: flowers_64/flowers/image_03742.jpg
#   inflating: flowers_64/flowers/image_03743.jpg
#   inflating: flowers_64/flowers/image_03744.jpg
#   inflating: flowers_64/flowers/image_03745.jpg
#   inflating: flowers_64/flowers/image_03746.jpg
#   inflating: flowers_64/flowers/image_03747.jpg
#   inflating: flowers_64/flowers/image_03748.jpg
#   inflating: flowers_64/flowers/image_03749.jpg
#   inflating: flowers_64/flowers/image_03750.jpg
#   inflating: flowers_64/flowers/image_03751.jpg
#   inflating: flowers_64/flowers/image_03752.jpg
#   inflating: flowers_64/flowers/image_03753.jpg
#   inflating: flowers_64/flowers/image_03754.jpg
#   inflating: flowers_64/flowers/image_03755.jpg
#   inflating: flowers_64/flowers/image_03756.jpg
#   inflating: flowers_64/flowers/image_03757.jpg
#   inflating: flowers_64/flowers/image_03758.jpg
#   inflating: flowers_64/flowers/image_03759.jpg
#   inflating: flowers_64/flowers/image_03760.jpg
#   inflating: flowers_64/flowers/image_03761.jpg
#   inflating: flowers_64/flowers/image_03762.jpg
#   inflating: flowers_64/flowers/image_03763.jpg
#   inflating: flowers_64/flowers/image_03764.jpg
#   inflating: flowers_64/flowers/image_03765.jpg
#   inflating: flowers_64/flowers/image_03766.jpg
#   inflating: flowers_64/flowers/image_03767.jpg
#   inflating: flowers_64/flowers/image_03768.jpg
#   inflating: flowers_64/flowers/image_03769.jpg
#   inflating: flowers_64/flowers/image_03770.jpg
#   inflating: flowers_64/flowers/image_03771.jpg
#   inflating: flowers_64/flowers/image_03772.jpg
#   inflating: flowers_64/flowers/image_03773.jpg
#   inflating: flowers_64/flowers/image_03774.jpg
#   inflating: flowers_64/flowers/image_03775.jpg
#   inflating: flowers_64/flowers/image_03776.jpg
#   inflating: flowers_64/flowers/image_03777.jpg
#   inflating: flowers_64/flowers/image_03778.jpg
#   inflating: flowers_64/flowers/image_03779.jpg
#   inflating: flowers_64/flowers/image_03780.jpg
#   inflating: flowers_64/flowers/image_03781.jpg
#   inflating: flowers_64/flowers/image_03782.jpg
#   inflating: flowers_64/flowers/image_03783.jpg
#   inflating: flowers_64/flowers/image_03784.jpg
#   inflating: flowers_64/flowers/image_03785.jpg
#   inflating: flowers_64/flowers/image_03786.jpg
#   inflating: flowers_64/flowers/image_03787.jpg
#   inflating: flowers_64/flowers/image_03788.jpg
#   inflating: flowers_64/flowers/image_03789.jpg
#   inflating: flowers_64/flowers/image_03790.jpg
#   inflating: flowers_64/flowers/image_03791.jpg
#   inflating: flowers_64/flowers/image_03792.jpg
#   inflating: flowers_64/flowers/image_03793.jpg
#   inflating: flowers_64/flowers/image_03794.jpg
#   inflating: flowers_64/flowers/image_03795.jpg
#   inflating: flowers_64/flowers/image_03796.jpg
#   inflating: flowers_64/flowers/image_03797.jpg
#   inflating: flowers_64/flowers/image_03798.jpg
#   inflating: flowers_64/flowers/image_03799.jpg
#   inflating: flowers_64/flowers/image_03800.jpg
#   inflating: flowers_64/flowers/image_03801.jpg
#   inflating: flowers_64/flowers/image_03802.jpg
#   inflating: flowers_64/flowers/image_03803.jpg
#   inflating: flowers_64/flowers/image_03804.jpg
#   inflating: flowers_64/flowers/image_03805.jpg
#   inflating: flowers_64/flowers/image_03806.jpg
#   inflating: flowers_64/flowers/image_03807.jpg
#   inflating: flowers_64/flowers/image_03808.jpg
#   inflating: flowers_64/flowers/image_03809.jpg
#   inflating: flowers_64/flowers/image_03810.jpg
#   inflating: flowers_64/flowers/image_03811.jpg
#   inflating: flowers_64/flowers/image_03812.jpg
#   inflating: flowers_64/flowers/image_03813.jpg
#   inflating: flowers_64/flowers/image_03814.jpg
#   inflating: flowers_64/flowers/image_03815.jpg
#   inflating: flowers_64/flowers/image_03816.jpg
#   inflating: flowers_64/flowers/image_03817.jpg
#   inflating: flowers_64/flowers/image_03818.jpg
#   inflating: flowers_64/flowers/image_03819.jpg
#   inflating: flowers_64/flowers/image_03820.jpg
#   inflating: flowers_64/flowers/image_03821.jpg
#   inflating: flowers_64/flowers/image_03822.jpg
#   inflating: flowers_64/flowers/image_03823.jpg
#   inflating: flowers_64/flowers/image_03824.jpg
#   inflating: flowers_64/flowers/image_03825.jpg
#   inflating: flowers_64/flowers/image_03826.jpg
#   inflating: flowers_64/flowers/image_03827.jpg
#   inflating: flowers_64/flowers/image_03828.jpg
#   inflating: flowers_64/flowers/image_03829.jpg
#   inflating: flowers_64/flowers/image_03830.jpg
#   inflating: flowers_64/flowers/image_03831.jpg
#   inflating: flowers_64/flowers/image_03832.jpg
#   inflating: flowers_64/flowers/image_03833.jpg
#   inflating: flowers_64/flowers/image_03834.jpg
#   inflating: flowers_64/flowers/image_03835.jpg
#   inflating: flowers_64/flowers/image_03836.jpg
#   inflating: flowers_64/flowers/image_03837.jpg
#   inflating: flowers_64/flowers/image_03838.jpg
#   inflating: flowers_64/flowers/image_03839.jpg
#   inflating: flowers_64/flowers/image_03840.jpg
#   inflating: flowers_64/flowers/image_03841.jpg
#   inflating: flowers_64/flowers/image_03842.jpg
#   inflating: flowers_64/flowers/image_03843.jpg
#   inflating: flowers_64/flowers/image_03844.jpg
#   inflating: flowers_64/flowers/image_03845.jpg
#   inflating: flowers_64/flowers/image_03846.jpg
#   inflating: flowers_64/flowers/image_03847.jpg
#   inflating: flowers_64/flowers/image_03848.jpg
#   inflating: flowers_64/flowers/image_03849.jpg
#   inflating: flowers_64/flowers/image_03850.jpg
#   inflating: flowers_64/flowers/image_03851.jpg
#   inflating: flowers_64/flowers/image_03852.jpg
#   inflating: flowers_64/flowers/image_03853.jpg
#   inflating: flowers_64/flowers/image_03854.jpg
#   inflating: flowers_64/flowers/image_03855.jpg
#   inflating: flowers_64/flowers/image_03856.jpg
#   inflating: flowers_64/flowers/image_03857.jpg
#   inflating: flowers_64/flowers/image_03858.jpg
#   inflating: flowers_64/flowers/image_03859.jpg
#   inflating: flowers_64/flowers/image_03860.jpg
#   inflating: flowers_64/flowers/image_03861.jpg
#   inflating: flowers_64/flowers/image_03862.jpg
#   inflating: flowers_64/flowers/image_03863.jpg
#   inflating: flowers_64/flowers/image_03864.jpg
#   inflating: flowers_64/flowers/image_03865.jpg
#   inflating: flowers_64/flowers/image_03866.jpg
#   inflating: flowers_64/flowers/image_03867.jpg
#   inflating: flowers_64/flowers/image_03868.jpg
#   inflating: flowers_64/flowers/image_03869.jpg
#   inflating: flowers_64/flowers/image_03870.jpg
#   inflating: flowers_64/flowers/image_03871.jpg
#   inflating: flowers_64/flowers/image_03872.jpg
#   inflating: flowers_64/flowers/image_03873.jpg
#   inflating: flowers_64/flowers/image_03874.jpg
#   inflating: flowers_64/flowers/image_03875.jpg
#   inflating: flowers_64/flowers/image_03876.jpg
#   inflating: flowers_64/flowers/image_03877.jpg
#   inflating: flowers_64/flowers/image_03878.jpg
#   inflating: flowers_64/flowers/image_03879.jpg
#   inflating: flowers_64/flowers/image_03880.jpg
#   inflating: flowers_64/flowers/image_03881.jpg
#   inflating: flowers_64/flowers/image_03882.jpg
#   inflating: flowers_64/flowers/image_03883.jpg
#   inflating: flowers_64/flowers/image_03884.jpg
#   inflating: flowers_64/flowers/image_03885.jpg
#   inflating: flowers_64/flowers/image_03886.jpg
#   inflating: flowers_64/flowers/image_03887.jpg
#   inflating: flowers_64/flowers/image_03888.jpg
#   inflating: flowers_64/flowers/image_03889.jpg
#   inflating: flowers_64/flowers/image_03890.jpg
#   inflating: flowers_64/flowers/image_03891.jpg
#   inflating: flowers_64/flowers/image_03892.jpg
#   inflating: flowers_64/flowers/image_03893.jpg
#   inflating: flowers_64/flowers/image_03894.jpg
#   inflating: flowers_64/flowers/image_03895.jpg
#   inflating: flowers_64/flowers/image_03896.jpg
#   inflating: flowers_64/flowers/image_03897.jpg
#   inflating: flowers_64/flowers/image_03898.jpg
#   inflating: flowers_64/flowers/image_03899.jpg
#   inflating: flowers_64/flowers/image_03900.jpg
#   inflating: flowers_64/flowers/image_03901.jpg
#   inflating: flowers_64/flowers/image_03902.jpg
#   inflating: flowers_64/flowers/image_03903.jpg
#   inflating: flowers_64/flowers/image_03904.jpg
#   inflating: flowers_64/flowers/image_03905.jpg
#   inflating: flowers_64/flowers/image_03906.jpg
#   inflating: flowers_64/flowers/image_03907.jpg
#   inflating: flowers_64/flowers/image_03908.jpg
#   inflating: flowers_64/flowers/image_03909.jpg
#   inflating: flowers_64/flowers/image_03910.jpg
#   inflating: flowers_64/flowers/image_03911.jpg
#   inflating: flowers_64/flowers/image_03912.jpg
#   inflating: flowers_64/flowers/image_03913.jpg
#   inflating: flowers_64/flowers/image_03914.jpg
#   inflating: flowers_64/flowers/image_03915.jpg
#   inflating: flowers_64/flowers/image_03916.jpg
#   inflating: flowers_64/flowers/image_03917.jpg
#   inflating: flowers_64/flowers/image_03918.jpg
#   inflating: flowers_64/flowers/image_03919.jpg
#   inflating: flowers_64/flowers/image_03920.jpg
#   inflating: flowers_64/flowers/image_03921.jpg
#   inflating: flowers_64/flowers/image_03922.jpg
#   inflating: flowers_64/flowers/image_03923.jpg
#   inflating: flowers_64/flowers/image_03924.jpg
#   inflating: flowers_64/flowers/image_03925.jpg
#   inflating: flowers_64/flowers/image_03926.jpg
#   inflating: flowers_64/flowers/image_03927.jpg
#   inflating: flowers_64/flowers/image_03928.jpg
#   inflating: flowers_64/flowers/image_03929.jpg
#   inflating: flowers_64/flowers/image_03930.jpg
#   inflating: flowers_64/flowers/image_03931.jpg
#   inflating: flowers_64/flowers/image_03932.jpg
#   inflating: flowers_64/flowers/image_03933.jpg
#   inflating: flowers_64/flowers/image_03934.jpg
#   inflating: flowers_64/flowers/image_03935.jpg
#   inflating: flowers_64/flowers/image_03936.jpg
#   inflating: flowers_64/flowers/image_03937.jpg
#   inflating: flowers_64/flowers/image_03938.jpg
#   inflating: flowers_64/flowers/image_03939.jpg
#   inflating: flowers_64/flowers/image_03940.jpg
#   inflating: flowers_64/flowers/image_03941.jpg
#   inflating: flowers_64/flowers/image_03942.jpg
#   inflating: flowers_64/flowers/image_03943.jpg
#   inflating: flowers_64/flowers/image_03944.jpg
#   inflating: flowers_64/flowers/image_03945.jpg
#   inflating: flowers_64/flowers/image_03946.jpg
#   inflating: flowers_64/flowers/image_03947.jpg
#   inflating: flowers_64/flowers/image_03948.jpg
#   inflating: flowers_64/flowers/image_03949.jpg
#   inflating: flowers_64/flowers/image_03950.jpg
#   inflating: flowers_64/flowers/image_03951.jpg
#   inflating: flowers_64/flowers/image_03952.jpg
#   inflating: flowers_64/flowers/image_03953.jpg
#   inflating: flowers_64/flowers/image_03954.jpg
#   inflating: flowers_64/flowers/image_03955.jpg
#   inflating: flowers_64/flowers/image_03956.jpg
#   inflating: flowers_64/flowers/image_03957.jpg
#   inflating: flowers_64/flowers/image_03958.jpg
#   inflating: flowers_64/flowers/image_03959.jpg
#   inflating: flowers_64/flowers/image_03960.jpg
#   inflating: flowers_64/flowers/image_03961.jpg
#   inflating: flowers_64/flowers/image_03962.jpg
#   inflating: flowers_64/flowers/image_03963.jpg
#   inflating: flowers_64/flowers/image_03964.jpg
#   inflating: flowers_64/flowers/image_03965.jpg
#   inflating: flowers_64/flowers/image_03966.jpg
#   inflating: flowers_64/flowers/image_03967.jpg
#   inflating: flowers_64/flowers/image_03968.jpg
#   inflating: flowers_64/flowers/image_03969.jpg
#   inflating: flowers_64/flowers/image_03970.jpg
#   inflating: flowers_64/flowers/image_03971.jpg
#   inflating: flowers_64/flowers/image_03972.jpg
#   inflating: flowers_64/flowers/image_03973.jpg
#   inflating: flowers_64/flowers/image_03974.jpg
#   inflating: flowers_64/flowers/image_03975.jpg
#   inflating: flowers_64/flowers/image_03976.jpg
#   inflating: flowers_64/flowers/image_03977.jpg
#   inflating: flowers_64/flowers/image_03978.jpg
#   inflating: flowers_64/flowers/image_03979.jpg
#   inflating: flowers_64/flowers/image_03980.jpg
#   inflating: flowers_64/flowers/image_03981.jpg
#   inflating: flowers_64/flowers/image_03982.jpg
#   inflating: flowers_64/flowers/image_03983.jpg
#   inflating: flowers_64/flowers/image_03984.jpg
#   inflating: flowers_64/flowers/image_03985.jpg
#   inflating: flowers_64/flowers/image_03986.jpg
#   inflating: flowers_64/flowers/image_03987.jpg
#   inflating: flowers_64/flowers/image_03988.jpg
#   inflating: flowers_64/flowers/image_03989.jpg
#   inflating: flowers_64/flowers/image_03990.jpg
#   inflating: flowers_64/flowers/image_03991.jpg
#   inflating: flowers_64/flowers/image_03992.jpg
#   inflating: flowers_64/flowers/image_03993.jpg
#   inflating: flowers_64/flowers/image_03994.jpg
#   inflating: flowers_64/flowers/image_03995.jpg
#   inflating: flowers_64/flowers/image_03996.jpg
#   inflating: flowers_64/flowers/image_03997.jpg
#   inflating: flowers_64/flowers/image_03998.jpg
#   inflating: flowers_64/flowers/image_03999.jpg
#   inflating: flowers_64/flowers/image_04000.jpg
#   inflating: flowers_64/flowers/image_04001.jpg
#   inflating: flowers_64/flowers/image_04002.jpg
#   inflating: flowers_64/flowers/image_04003.jpg
#   inflating: flowers_64/flowers/image_04004.jpg
#   inflating: flowers_64/flowers/image_04005.jpg
#   inflating: flowers_64/flowers/image_04006.jpg
#   inflating: flowers_64/flowers/image_04007.jpg
#   inflating: flowers_64/flowers/image_04008.jpg
#   inflating: flowers_64/flowers/image_04009.jpg
#   inflating: flowers_64/flowers/image_04010.jpg
#   inflating: flowers_64/flowers/image_04011.jpg
#   inflating: flowers_64/flowers/image_04012.jpg
#   inflating: flowers_64/flowers/image_04013.jpg
#   inflating: flowers_64/flowers/image_04014.jpg
#   inflating: flowers_64/flowers/image_04015.jpg
#   inflating: flowers_64/flowers/image_04016.jpg
#   inflating: flowers_64/flowers/image_04017.jpg
#   inflating: flowers_64/flowers/image_04018.jpg
#   inflating: flowers_64/flowers/image_04019.jpg
#   inflating: flowers_64/flowers/image_04020.jpg
#   inflating: flowers_64/flowers/image_04021.jpg
#   inflating: flowers_64/flowers/image_04022.jpg
#   inflating: flowers_64/flowers/image_04023.jpg
#   inflating: flowers_64/flowers/image_04024.jpg
#   inflating: flowers_64/flowers/image_04025.jpg
#   inflating: flowers_64/flowers/image_04026.jpg
#   inflating: flowers_64/flowers/image_04027.jpg
#   inflating: flowers_64/flowers/image_04028.jpg
#   inflating: flowers_64/flowers/image_04029.jpg
#   inflating: flowers_64/flowers/image_04030.jpg
#   inflating: flowers_64/flowers/image_04031.jpg
#   inflating: flowers_64/flowers/image_04032.jpg
#   inflating: flowers_64/flowers/image_04033.jpg
#   inflating: flowers_64/flowers/image_04034.jpg
#   inflating: flowers_64/flowers/image_04035.jpg
#   inflating: flowers_64/flowers/image_04036.jpg
#   inflating: flowers_64/flowers/image_04037.jpg
#   inflating: flowers_64/flowers/image_04038.jpg
#   inflating: flowers_64/flowers/image_04039.jpg
#   inflating: flowers_64/flowers/image_04040.jpg
#   inflating: flowers_64/flowers/image_04041.jpg
#   inflating: flowers_64/flowers/image_04042.jpg
#   inflating: flowers_64/flowers/image_04043.jpg
#   inflating: flowers_64/flowers/image_04044.jpg
#   inflating: flowers_64/flowers/image_04045.jpg
#   inflating: flowers_64/flowers/image_04046.jpg
#   inflating: flowers_64/flowers/image_04047.jpg
#   inflating: flowers_64/flowers/image_04048.jpg
#   inflating: flowers_64/flowers/image_04049.jpg
#   inflating: flowers_64/flowers/image_04050.jpg
#   inflating: flowers_64/flowers/image_04051.jpg
#   inflating: flowers_64/flowers/image_04052.jpg
#   inflating: flowers_64/flowers/image_04053.jpg
#   inflating: flowers_64/flowers/image_04054.jpg
#   inflating: flowers_64/flowers/image_04055.jpg
#   inflating: flowers_64/flowers/image_04056.jpg
#   inflating: flowers_64/flowers/image_04057.jpg
#   inflating: flowers_64/flowers/image_04058.jpg
#   inflating: flowers_64/flowers/image_04059.jpg
#   inflating: flowers_64/flowers/image_04060.jpg
#   inflating: flowers_64/flowers/image_04061.jpg
#   inflating: flowers_64/flowers/image_04062.jpg
#   inflating: flowers_64/flowers/image_04063.jpg
#   inflating: flowers_64/flowers/image_04064.jpg
#   inflating: flowers_64/flowers/image_04065.jpg
#   inflating: flowers_64/flowers/image_04066.jpg
#   inflating: flowers_64/flowers/image_04067.jpg
#   inflating: flowers_64/flowers/image_04068.jpg
#   inflating: flowers_64/flowers/image_04069.jpg
#   inflating: flowers_64/flowers/image_04070.jpg
#   inflating: flowers_64/flowers/image_04071.jpg
#   inflating: flowers_64/flowers/image_04072.jpg
#   inflating: flowers_64/flowers/image_04073.jpg
#   inflating: flowers_64/flowers/image_04074.jpg
#   inflating: flowers_64/flowers/image_04075.jpg
#   inflating: flowers_64/flowers/image_04076.jpg
#   inflating: flowers_64/flowers/image_04077.jpg
#   inflating: flowers_64/flowers/image_04078.jpg
#   inflating: flowers_64/flowers/image_04079.jpg
#   inflating: flowers_64/flowers/image_04080.jpg
#   inflating: flowers_64/flowers/image_04081.jpg
#   inflating: flowers_64/flowers/image_04082.jpg
#   inflating: flowers_64/flowers/image_04083.jpg
#   inflating: flowers_64/flowers/image_04084.jpg
#   inflating: flowers_64/flowers/image_04085.jpg
#   inflating: flowers_64/flowers/image_04086.jpg
#   inflating: flowers_64/flowers/image_04087.jpg
#   inflating: flowers_64/flowers/image_04088.jpg
#   inflating: flowers_64/flowers/image_04089.jpg
#   inflating: flowers_64/flowers/image_04090.jpg
#   inflating: flowers_64/flowers/image_04091.jpg
#   inflating: flowers_64/flowers/image_04092.jpg
#   inflating: flowers_64/flowers/image_04093.jpg
#   inflating: flowers_64/flowers/image_04094.jpg
#   inflating: flowers_64/flowers/image_04095.jpg
#   inflating: flowers_64/flowers/image_04096.jpg
#   inflating: flowers_64/flowers/image_04097.jpg
#   inflating: flowers_64/flowers/image_04098.jpg
#   inflating: flowers_64/flowers/image_04099.jpg
#   inflating: flowers_64/flowers/image_04100.jpg
#   inflating: flowers_64/flowers/image_04101.jpg
#   inflating: flowers_64/flowers/image_04102.jpg
#   inflating: flowers_64/flowers/image_04103.jpg
#   inflating: flowers_64/flowers/image_04104.jpg
#   inflating: flowers_64/flowers/image_04105.jpg
#   inflating: flowers_64/flowers/image_04106.jpg
#   inflating: flowers_64/flowers/image_04107.jpg
#   inflating: flowers_64/flowers/image_04108.jpg
#   inflating: flowers_64/flowers/image_04109.jpg
#   inflating: flowers_64/flowers/image_04110.jpg
#   inflating: flowers_64/flowers/image_04111.jpg
#   inflating: flowers_64/flowers/image_04112.jpg
#   inflating: flowers_64/flowers/image_04113.jpg
#   inflating: flowers_64/flowers/image_04114.jpg
#   inflating: flowers_64/flowers/image_04115.jpg
#   inflating: flowers_64/flowers/image_04116.jpg
#   inflating: flowers_64/flowers/image_04117.jpg
#   inflating: flowers_64/flowers/image_04118.jpg
#   inflating: flowers_64/flowers/image_04119.jpg
#   inflating: flowers_64/flowers/image_04120.jpg
#   inflating: flowers_64/flowers/image_04121.jpg
#   inflating: flowers_64/flowers/image_04122.jpg
#   inflating: flowers_64/flowers/image_04123.jpg
#   inflating: flowers_64/flowers/image_04124.jpg
#   inflating: flowers_64/flowers/image_04125.jpg
#   inflating: flowers_64/flowers/image_04126.jpg
#   inflating: flowers_64/flowers/image_04127.jpg
#   inflating: flowers_64/flowers/image_04128.jpg
#   inflating: flowers_64/flowers/image_04129.jpg
#   inflating: flowers_64/flowers/image_04130.jpg
#   inflating: flowers_64/flowers/image_04131.jpg
#   inflating: flowers_64/flowers/image_04132.jpg
#   inflating: flowers_64/flowers/image_04133.jpg
#   inflating: flowers_64/flowers/image_04134.jpg
#   inflating: flowers_64/flowers/image_04135.jpg
#   inflating: flowers_64/flowers/image_04136.jpg
#   inflating: flowers_64/flowers/image_04137.jpg
#   inflating: flowers_64/flowers/image_04138.jpg
#   inflating: flowers_64/flowers/image_04139.jpg
#   inflating: flowers_64/flowers/image_04140.jpg
#   inflating: flowers_64/flowers/image_04141.jpg
#   inflating: flowers_64/flowers/image_04142.jpg
#   inflating: flowers_64/flowers/image_04143.jpg
#   inflating: flowers_64/flowers/image_04144.jpg
#   inflating: flowers_64/flowers/image_04145.jpg
#   inflating: flowers_64/flowers/image_04146.jpg
#   inflating: flowers_64/flowers/image_04147.jpg
# ...
#   inflating: flowers_64/flowers/image_07870.jpg
#   inflating: flowers_64/flowers/image_07871.jpg
#   inflating: flowers_64/flowers/image_07872.jpg
#   inflating: flowers_64/flowers/image_07873.jpg
#   inflating: flowers_64/flowers/image_07874.jpg
#   inflating: flowers_64/flowers/image_07875.jpg
#   inflating: flowers_64/flowers/image_07876.jpg
#   inflating: flowers_64/flowers/image_07877.jpg
#   inflating: flowers_64/flowers/image_07878.jpg
#   inflating: flowers_64/flowers/image_07879.jpg
#   inflating: flowers_64/flowers/image_07880.jpg
#   inflating: flowers_64/flowers/image_07881.jpg
#   inflating: flowers_64/flowers/image_07882.jpg
#   inflating: flowers_64/flowers/image_07883.jpg
#   inflating: flowers_64/flowers/image_07884.jpg
#   inflating: flowers_64/flowers/image_07885.jpg
#   inflating: flowers_64/flowers/image_07886.jpg
#   inflating: flowers_64/flowers/image_07887.jpg
#   inflating: flowers_64/flowers/image_07888.jpg
#   inflating: flowers_64/flowers/image_07889.jpg
#   inflating: flowers_64/flowers/image_07890.jpg
#   inflating: flowers_64/flowers/image_07891.jpg
#   inflating: flowers_64/flowers/image_07892.jpg
#   inflating: flowers_64/flowers/image_07893.jpg
#   inflating: flowers_64/flowers/image_07894.jpg
#   inflating: flowers_64/flowers/image_07895.jpg
#   inflating: flowers_64/flowers/image_07896.jpg
#   inflating: flowers_64/flowers/image_07897.jpg
#   inflating: flowers_64/flowers/image_07898.jpg
#   inflating: flowers_64/flowers/image_07899.jpg
#   inflating: flowers_64/flowers/image_07900.jpg
#   inflating: flowers_64/flowers/image_07901.jpg
#   inflating: flowers_64/flowers/image_07902.jpg
#   inflating: flowers_64/flowers/image_07903.jpg
#   inflating: flowers_64/flowers/image_07904.jpg
#   inflating: flowers_64/flowers/image_07905.jpg
#   inflating: flowers_64/flowers/image_07906.jpg
#   inflating: flowers_64/flowers/image_07907.jpg
#   inflating: flowers_64/flowers/image_07908.jpg
#   inflating: flowers_64/flowers/image_07909.jpg
#   inflating: flowers_64/flowers/image_07910.jpg
#   inflating: flowers_64/flowers/image_07911.jpg
#   inflating: flowers_64/flowers/image_07912.jpg
#   inflating: flowers_64/flowers/image_07913.jpg
#   inflating: flowers_64/flowers/image_07914.jpg
#   inflating: flowers_64/flowers/image_07915.jpg
#   inflating: flowers_64/flowers/image_07916.jpg
#   inflating: flowers_64/flowers/image_07917.jpg
#   inflating: flowers_64/flowers/image_07918.jpg
#   inflating: flowers_64/flowers/image_07919.jpg
#   inflating: flowers_64/flowers/image_07920.jpg
#   inflating: flowers_64/flowers/image_07921.jpg
#   inflating: flowers_64/flowers/image_07922.jpg
#   inflating: flowers_64/flowers/image_07923.jpg
#   inflating: flowers_64/flowers/image_07924.jpg
#   inflating: flowers_64/flowers/image_07925.jpg
#   inflating: flowers_64/flowers/image_07926.jpg
#   inflating: flowers_64/flowers/image_07927.jpg
#   inflating: flowers_64/flowers/image_07928.jpg
#   inflating: flowers_64/flowers/image_07929.jpg
#   inflating: flowers_64/flowers/image_07930.jpg
#   inflating: flowers_64/flowers/image_07931.jpg
#   inflating: flowers_64/flowers/image_07932.jpg
#   inflating: flowers_64/flowers/image_07933.jpg
#   inflating: flowers_64/flowers/image_07934.jpg
#   inflating: flowers_64/flowers/image_07935.jpg
#   inflating: flowers_64/flowers/image_07936.jpg
#   inflating: flowers_64/flowers/image_07937.jpg
#   inflating: flowers_64/flowers/image_07938.jpg
#   inflating: flowers_64/flowers/image_07939.jpg
#   inflating: flowers_64/flowers/image_07940.jpg
#   inflating: flowers_64/flowers/image_07941.jpg
#   inflating: flowers_64/flowers/image_07942.jpg
#   inflating: flowers_64/flowers/image_07943.jpg
#   inflating: flowers_64/flowers/image_07944.jpg
#   inflating: flowers_64/flowers/image_07945.jpg
#   inflating: flowers_64/flowers/image_07946.jpg
#   inflating: flowers_64/flowers/image_07947.jpg
#   inflating: flowers_64/flowers/image_07948.jpg
#   inflating: flowers_64/flowers/image_07949.jpg
#   inflating: flowers_64/flowers/image_07950.jpg
#   inflating: flowers_64/flowers/image_07951.jpg
#   inflating: flowers_64/flowers/image_07952.jpg
#   inflating: flowers_64/flowers/image_07953.jpg
#   inflating: flowers_64/flowers/image_07954.jpg
#   inflating: flowers_64/flowers/image_07955.jpg
#   inflating: flowers_64/flowers/image_07956.jpg
#   inflating: flowers_64/flowers/image_07957.jpg
#   inflating: flowers_64/flowers/image_07958.jpg
#   inflating: flowers_64/flowers/image_07959.jpg
#   inflating: flowers_64/flowers/image_07960.jpg
#   inflating: flowers_64/flowers/image_07961.jpg
#   inflating: flowers_64/flowers/image_07962.jpg
#   inflating: flowers_64/flowers/image_07963.jpg
#   inflating: flowers_64/flowers/image_07964.jpg
#   inflating: flowers_64/flowers/image_07965.jpg
#   inflating: flowers_64/flowers/image_07966.jpg
#   inflating: flowers_64/flowers/image_07967.jpg
#   inflating: flowers_64/flowers/image_07968.jpg
#   inflating: flowers_64/flowers/image_07969.jpg
#   inflating: flowers_64/flowers/image_07970.jpg
#   inflating: flowers_64/flowers/image_07971.jpg
#   inflating: flowers_64/flowers/image_07972.jpg
#   inflating: flowers_64/flowers/image_07973.jpg
#   inflating: flowers_64/flowers/image_07974.jpg
#   inflating: flowers_64/flowers/image_07975.jpg
#   inflating: flowers_64/flowers/image_07976.jpg
#   inflating: flowers_64/flowers/image_07977.jpg
#   inflating: flowers_64/flowers/image_07978.jpg
#   inflating: flowers_64/flowers/image_07979.jpg
#   inflating: flowers_64/flowers/image_07980.jpg
#   inflating: flowers_64/flowers/image_07981.jpg
#   inflating: flowers_64/flowers/image_07982.jpg
#   inflating: flowers_64/flowers/image_07983.jpg
#   inflating: flowers_64/flowers/image_07984.jpg
#   inflating: flowers_64/flowers/image_07985.jpg
#   inflating: flowers_64/flowers/image_07986.jpg
#   inflating: flowers_64/flowers/image_07987.jpg
#   inflating: flowers_64/flowers/image_07988.jpg
#   inflating: flowers_64/flowers/image_07989.jpg
#   inflating: flowers_64/flowers/image_07990.jpg
#   inflating: flowers_64/flowers/image_07991.jpg
#   inflating: flowers_64/flowers/image_07992.jpg
#   inflating: flowers_64/flowers/image_07993.jpg
#   inflating: flowers_64/flowers/image_07994.jpg
#   inflating: flowers_64/flowers/image_07995.jpg
#   inflating: flowers_64/flowers/image_07996.jpg
#   inflating: flowers_64/flowers/image_07997.jpg
#   inflating: flowers_64/flowers/image_07998.jpg
#   inflating: flowers_64/flowers/image_07999.jpg
#   inflating: flowers_64/flowers/image_08000.jpg
#   inflating: flowers_64/flowers/image_08001.jpg
#   inflating: flowers_64/flowers/image_08002.jpg
#   inflating: flowers_64/flowers/image_08003.jpg
#   inflating: flowers_64/flowers/image_08004.jpg
#   inflating: flowers_64/flowers/image_08005.jpg
#   inflating: flowers_64/flowers/image_08006.jpg
#   inflating: flowers_64/flowers/image_08007.jpg
#   inflating: flowers_64/flowers/image_08008.jpg
#   inflating: flowers_64/flowers/image_08009.jpg
#   inflating: flowers_64/flowers/image_08010.jpg
#   inflating: flowers_64/flowers/image_08011.jpg
#   inflating: flowers_64/flowers/image_08012.jpg
#   inflating: flowers_64/flowers/image_08013.jpg
#   inflating: flowers_64/flowers/image_08014.jpg
#   inflating: flowers_64/flowers/image_08015.jpg
#   inflating: flowers_64/flowers/image_08016.jpg
#   inflating: flowers_64/flowers/image_08017.jpg
#   inflating: flowers_64/flowers/image_08018.jpg
#   inflating: flowers_64/flowers/image_08019.jpg
#   inflating: flowers_64/flowers/image_08020.jpg
#   inflating: flowers_64/flowers/image_08021.jpg
#   inflating: flowers_64/flowers/image_08022.jpg
#   inflating: flowers_64/flowers/image_08023.jpg
#   inflating: flowers_64/flowers/image_08024.jpg
#   inflating: flowers_64/flowers/image_08025.jpg
#   inflating: flowers_64/flowers/image_08026.jpg
#   inflating: flowers_64/flowers/image_08027.jpg
#   inflating: flowers_64/flowers/image_08028.jpg
#   inflating: flowers_64/flowers/image_08029.jpg
#   inflating: flowers_64/flowers/image_08030.jpg
#   inflating: flowers_64/flowers/image_08031.jpg
#   inflating: flowers_64/flowers/image_08032.jpg
#   inflating: flowers_64/flowers/image_08033.jpg
#   inflating: flowers_64/flowers/image_08034.jpg
#   inflating: flowers_64/flowers/image_08035.jpg
#   inflating: flowers_64/flowers/image_08036.jpg
#   inflating: flowers_64/flowers/image_08037.jpg
#   inflating: flowers_64/flowers/image_08038.jpg
#   inflating: flowers_64/flowers/image_08039.jpg
#   inflating: flowers_64/flowers/image_08040.jpg
#   inflating: flowers_64/flowers/image_08041.jpg
#   inflating: flowers_64/flowers/image_08042.jpg
#   inflating: flowers_64/flowers/image_08043.jpg
#   inflating: flowers_64/flowers/image_08044.jpg
#   inflating: flowers_64/flowers/image_08045.jpg
#   inflating: flowers_64/flowers/image_08046.jpg
#   inflating: flowers_64/flowers/image_08047.jpg
#   inflating: flowers_64/flowers/image_08048.jpg
#   inflating: flowers_64/flowers/image_08049.jpg
#   inflating: flowers_64/flowers/image_08050.jpg
#   inflating: flowers_64/flowers/image_08051.jpg
#   inflating: flowers_64/flowers/image_08052.jpg
#   inflating: flowers_64/flowers/image_08053.jpg
#   inflating: flowers_64/flowers/image_08054.jpg
#   inflating: flowers_64/flowers/image_08055.jpg
#   inflating: flowers_64/flowers/image_08056.jpg
#   inflating: flowers_64/flowers/image_08057.jpg
#   inflating: flowers_64/flowers/image_08058.jpg
#   inflating: flowers_64/flowers/image_08059.jpg
#   inflating: flowers_64/flowers/image_08060.jpg
#   inflating: flowers_64/flowers/image_08061.jpg
#   inflating: flowers_64/flowers/image_08062.jpg
#   inflating: flowers_64/flowers/image_08063.jpg
#   inflating: flowers_64/flowers/image_08064.jpg
#   inflating: flowers_64/flowers/image_08065.jpg
#   inflating: flowers_64/flowers/image_08066.jpg
#   inflating: flowers_64/flowers/image_08067.jpg
#   inflating: flowers_64/flowers/image_08068.jpg
#   inflating: flowers_64/flowers/image_08069.jpg
#   inflating: flowers_64/flowers/image_08070.jpg
#   inflating: flowers_64/flowers/image_08071.jpg
#   inflating: flowers_64/flowers/image_08072.jpg
#   inflating: flowers_64/flowers/image_08073.jpg
#   inflating: flowers_64/flowers/image_08074.jpg
#   inflating: flowers_64/flowers/image_08075.jpg
#   inflating: flowers_64/flowers/image_08076.jpg
#   inflating: flowers_64/flowers/image_08077.jpg
#   inflating: flowers_64/flowers/image_08078.jpg
#   inflating: flowers_64/flowers/image_08079.jpg
#   inflating: flowers_64/flowers/image_08080.jpg
#   inflating: flowers_64/flowers/image_08081.jpg
#   inflating: flowers_64/flowers/image_08082.jpg
#   inflating: flowers_64/flowers/image_08083.jpg
#   inflating: flowers_64/flowers/image_08084.jpg
#   inflating: flowers_64/flowers/image_08085.jpg
#   inflating: flowers_64/flowers/image_08086.jpg
#   inflating: flowers_64/flowers/image_08087.jpg
#   inflating: flowers_64/flowers/image_08088.jpg
#   inflating: flowers_64/flowers/image_08089.jpg
#   inflating: flowers_64/flowers/image_08090.jpg
#   inflating: flowers_64/flowers/image_08091.jpg
#   inflating: flowers_64/flowers/image_08092.jpg
#   inflating: flowers_64/flowers/image_08093.jpg
#   inflating: flowers_64/flowers/image_08094.jpg
#   inflating: flowers_64/flowers/image_08095.jpg
#   inflating: flowers_64/flowers/image_08096.jpg
#   inflating: flowers_64/flowers/image_08097.jpg
#   inflating: flowers_64/flowers/image_08098.jpg
#   inflating: flowers_64/flowers/image_08099.jpg
#   inflating: flowers_64/flowers/image_08100.jpg
#   inflating: flowers_64/flowers/image_08101.jpg
#   inflating: flowers_64/flowers/image_08102.jpg
#   inflating: flowers_64/flowers/image_08103.jpg
#   inflating: flowers_64/flowers/image_08104.jpg
#   inflating: flowers_64/flowers/image_08105.jpg
#   inflating: flowers_64/flowers/image_08106.jpg
#   inflating: flowers_64/flowers/image_08107.jpg
#   inflating: flowers_64/flowers/image_08108.jpg
#   inflating: flowers_64/flowers/image_08109.jpg
#   inflating: flowers_64/flowers/image_08110.jpg
#   inflating: flowers_64/flowers/image_08111.jpg
#   inflating: flowers_64/flowers/image_08112.jpg
#   inflating: flowers_64/flowers/image_08113.jpg
#   inflating: flowers_64/flowers/image_08114.jpg
#   inflating: flowers_64/flowers/image_08115.jpg
#   inflating: flowers_64/flowers/image_08116.jpg
#   inflating: flowers_64/flowers/image_08117.jpg
#   inflating: flowers_64/flowers/image_08118.jpg
#   inflating: flowers_64/flowers/image_08119.jpg
#   inflating: flowers_64/flowers/image_08120.jpg
#   inflating: flowers_64/flowers/image_08121.jpg
#   inflating: flowers_64/flowers/image_08122.jpg
#   inflating: flowers_64/flowers/image_08123.jpg
#   inflating: flowers_64/flowers/image_08124.jpg
#   inflating: flowers_64/flowers/image_08125.jpg
#   inflating: flowers_64/flowers/image_08126.jpg
#   inflating: flowers_64/flowers/image_08127.jpg
#   inflating: flowers_64/flowers/image_08128.jpg
#   inflating: flowers_64/flowers/image_08129.jpg
#   inflating: flowers_64/flowers/image_08130.jpg
#   inflating: flowers_64/flowers/image_08131.jpg
#   inflating: flowers_64/flowers/image_08132.jpg
#   inflating: flowers_64/flowers/image_08133.jpg
#   inflating: flowers_64/flowers/image_08134.jpg
#   inflating: flowers_64/flowers/image_08135.jpg
#   inflating: flowers_64/flowers/image_08136.jpg
#   inflating: flowers_64/flowers/image_08137.jpg
#   inflating: flowers_64/flowers/image_08138.jpg
#   inflating: flowers_64/flowers/image_08139.jpg
#   inflating: flowers_64/flowers/image_08140.jpg
#   inflating: flowers_64/flowers/image_08141.jpg
#   inflating: flowers_64/flowers/image_08142.jpg
#   inflating: flowers_64/flowers/image_08143.jpg
#   inflating: flowers_64/flowers/image_08144.jpg
#   inflating: flowers_64/flowers/image_08145.jpg
#   inflating: flowers_64/flowers/image_08146.jpg
#   inflating: flowers_64/flowers/image_08147.jpg
#   inflating: flowers_64/flowers/image_08148.jpg
#   inflating: flowers_64/flowers/image_08149.jpg
#   inflating: flowers_64/flowers/image_08150.jpg
#   inflating: flowers_64/flowers/image_08151.jpg
#   inflating: flowers_64/flowers/image_08152.jpg
#   inflating: flowers_64/flowers/image_08153.jpg
#   inflating: flowers_64/flowers/image_08154.jpg
#   inflating: flowers_64/flowers/image_08155.jpg
#   inflating: flowers_64/flowers/image_08156.jpg
#   inflating: flowers_64/flowers/image_08157.jpg
#   inflating: flowers_64/flowers/image_08158.jpg
#   inflating: flowers_64/flowers/image_08159.jpg
#   inflating: flowers_64/flowers/image_08160.jpg
#   inflating: flowers_64/flowers/image_08161.jpg
#   inflating: flowers_64/flowers/image_08162.jpg
#   inflating: flowers_64/flowers/image_08163.jpg
#   inflating: flowers_64/flowers/image_08164.jpg
#   inflating: flowers_64/flowers/image_08165.jpg
#   inflating: flowers_64/flowers/image_08166.jpg
#   inflating: flowers_64/flowers/image_08167.jpg
#   inflating: flowers_64/flowers/image_08168.jpg
#   inflating: flowers_64/flowers/image_08169.jpg
#   inflating: flowers_64/flowers/image_08170.jpg
#   inflating: flowers_64/flowers/image_08171.jpg
#   inflating: flowers_64/flowers/image_08172.jpg
#   inflating: flowers_64/flowers/image_08173.jpg
#   inflating: flowers_64/flowers/image_08174.jpg
#   inflating: flowers_64/flowers/image_08175.jpg
#   inflating: flowers_64/flowers/image_08176.jpg
#   inflating: flowers_64/flowers/image_08177.jpg
#   inflating: flowers_64/flowers/image_08178.jpg
#   inflating: flowers_64/flowers/image_08179.jpg
#   inflating: flowers_64/flowers/image_08180.jpg
#   inflating: flowers_64/flowers/image_08181.jpg
#   inflating: flowers_64/flowers/image_08182.jpg
#   inflating: flowers_64/flowers/image_08183.jpg
#   inflating: flowers_64/flowers/image_08184.jpg
#   inflating: flowers_64/flowers/image_08185.jpg
#   inflating: flowers_64/flowers/image_08186.jpg
#   inflating: flowers_64/flowers/image_08187.jpg
#   inflating: flowers_64/flowers/image_08188.jpg
#   inflating: flowers_64/flowers/image_08189.jpg

# %% [markdown]
# We now import the CIFAR dataset and normalize the data.

# %%
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import os

directory = '/content/flowers_64'

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.43531922, 0.37799895, 0.29074696], std=[0.24403198, 0.19294092, 0.19901074])
])

dataset = torchvision.datasets.ImageFolder(root=directory, transform=transform)

batch_size = 32
train_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

mean = [0.43531922, 0.37799895, 0.29074696]
std = [0.24403198, 0.19294092, 0.19901074]

def denormalize(img):
    img = img.numpy()
    for i in range(3):
        img[i] = img[i] * std[i] + mean[i]
    return img

def imshow(img):
    img = denormalize(img)
    plt.imshow(np.transpose(img, (1, 2, 0)))
    plt.show()

data_iter = iter(train_loader)
images, _ = next(data_iter)

imshow(torchvision.utils.make_grid(images))

# %% [markdown]
# We can now train our model by training both eta and the velocity b.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")




base_lr = 1e-4
bs = 64

path = 'one-sided-linear'
interpolant  = Interpolant(path=path, gamma_type='')

b = Unet(dim=32).to(device)
eta = Unet(dim=32).to(device)
opt_b     = torch.optim.Adam(  b.parameters(), lr=base_lr)
opt_eta   = torch.optim.Adam(eta.parameters(), lr=base_lr)
#sched_b   = torch.optim.lr_scheduler.StepLR(optimizer=  opt_b, step_size=1500, gamma=0.4)
#sched_eta = torch.optim.lr_scheduler.StepLR(optimizer=opt_eta, step_size=1500, gamma=0.4)

import torch

opt_b = torch.optim.Adam(b.parameters(), lr=1e-4)
opt_eta = torch.optim.Adam(eta.parameters(), lr=1e-4)
epochs = 30
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n = len(train_loader)
for epoch in range(epochs):
    b.train()
    eta.train()
    epoch_loss = 0
    for x1, label in train_loader:
        x1 = x1.to(device)
        x0 = torch.randn_like(x1).to(device)

        ts = torch.rand(size=(x1.shape[0],)).to(device)

        loss_b = make_loss(loss_per_sample_b_one_sided, b, x0, x1, ts, interpolant)
        loss_eta = make_loss(loss_per_sample_one_sided_eta, eta, x0, x1, ts, interpolant)
        loss = loss_b + loss_eta
        epoch_loss += loss.item()/n
        opt_b.zero_grad()
        opt_eta.zero_grad()
        loss_b.backward()
        loss_eta.backward()
        opt_b.step()
        opt_eta.step()
        #sched_b.step()
        #sched_eta.step()

    print(f'Epoch {epoch+1}/{epochs}, Loss: {epoch_loss}')
# Out:
# Epoch 1/30, Loss: -6080.812042474747
# Epoch 2/30, Loss: -9689.7292137146
# Epoch 3/30, Loss: -11212.537109375
# Epoch 4/30, Loss: -12125.471061706543
# Epoch 5/30, Loss: -13044.53385925293
# Epoch 6/30, Loss: -13702.914024353027
# Epoch 7/30, Loss: -14307.248985290527
# Epoch 8/30, Loss: -14672.111000061035
# Epoch 9/30, Loss: -14946.685928344727
# Epoch 10/30, Loss: -15186.455291748047
# Epoch 11/30, Loss: -15334.691993713379
# Epoch 12/30, Loss: -15482.724784851074
# Epoch 13/30, Loss: -15608.56160736084
# Epoch 14/30, Loss: -15677.898895263672
# Epoch 15/30, Loss: -15788.26667022705
# Epoch 16/30, Loss: -15907.504020690918
# Epoch 17/30, Loss: -15963.348678588867
# Epoch 18/30, Loss: -16061.349021911621
# Epoch 19/30, Loss: -16154.264541625977
# Epoch 20/30, Loss: -16210.5796585083
# Epoch 21/30, Loss: -16199.982627868652
# Epoch 22/30, Loss: -16291.971939086914
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-1c5999cb9f45> in <cell line: 31>()
#      42         loss_eta = make_loss(loss_per_sample_one_sided_eta, eta, x0, x1, ts, interpolant)
#      43         loss = loss_b + loss_eta
# ---> 44         epoch_loss += loss.item()/n
#      45         opt_b.zero_grad()
#      46         opt_eta.zero_grad()
#
# KeyboardInterrupt:

# %% [markdown]
# We now can visualize our results using our models trained to estimate the velocity and the score and use the forward Fokker-Plank equation (SDE) to generate new samples.

# %%
s = SFromEta(eta, interpolant.a)

sde_flow = SDEIntegrator(b=b, s=s, eps=torch.tensor(0.01), n_save=4, start_end=(0.0001, 0.999), n_step=10**2).to(device)
# pflow = PFlowIntegrator(b=b,  method='dopri5', interpolant=interpolant, n_step=3) ODE
bs = 64
with torch.no_grad():
    x0_tests  = torch.randn(bs,3, 64, 64).to(device)
    xfs_sde   = sde_flow.rollout_forward(x0_tests, 'heun')
    xf_sde    = grab(xfs_sde[-1].squeeze())
    xf_sde = xf_sde.reshape(64,3,64,64)
    imshow(torchvision.utils.make_grid(torch.tensor(xf_sde)))
    plt.tight_layout()
    plt.show()

    xf_sde_4 = xf_sde[:4]


for k in range(4):
  imshow(torch.tensor(xf_sde_4[k]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
